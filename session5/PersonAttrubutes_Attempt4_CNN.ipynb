# %%
use_google_colab = True

# %%
# mount gdrive
if use_google_colab:
    from google.colab import drive
    drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# unzip data
if use_google_colab:
    # !unzip -q "/content/gdrive/My Drive/TSAI/session5/hvc_data.zip"
    # look for `hvc_annotations.csv` file and `resized` dir
    # %ls
# Out:
# gdrive/  hvc_annotations.csv  resized/  sample_data/

# %%
if use_google_colab:
  # %tensorflow_version 1.x

import cv2
import json

import numpy as np
import pandas as pd
import os

from functools import partial
from pathlib import Path 
from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

from keras.applications import VGG16

from keras.layers import Dense, Conv2D, BatchNormalization, Activation, SeparableConv2D
from keras.layers import AveragePooling2D, Input, Flatten, Convolution2D
from keras.layers import GlobalAveragePooling2D, Dropout, MaxPooling2D
from keras.models import Model, Sequential
from keras.optimizers import Adam
from keras.optimizers import SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2

from keras.preprocessing import image
from keras.utils.vis_utils import plot_model

from keras import backend as K

import matplotlib.pyplot as plt
# %matplotlib inline

if use_google_colab:
    from google.colab.patches import cv2_imshow
# Out:
# Using TensorFlow backend.

# %%
# load annotations
df = pd.read_csv("hvc_annotations.csv")
del df["filename"] # remove unwanted column

print("Shape: ", df.shape)
df.head(3)
# Out:
# Shape:  (13573, 9)
#    gender imagequality    age  ...        emotion        bodypose     image_path
# 0    male      Average  35-45  ...        Neutral  Front-Frontish  resized/1.jpg
# 1  female      Average  35-45  ...  Angry/Serious  Front-Frontish  resized/2.jpg
# 2    male         Good  45-55  ...        Neutral  Front-Frontish  resized/3.jpg
#
# [3 rows x 9 columns]

# %%
# visualize few images
fig = plt.figure(figsize=(8,3))
for i in range(10):
  ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
  img = image.load_img(df.image_path[i])
  plt.imshow(img)
plt.show()

# %%
# utility function to view image properties and its labeling
def viewData(index):
  img = image.load_img(df.image_path[index])
  plt.imshow(img)
  print(df.iloc[index])

# %%
viewData(4864) # typical case of wrong labeling (Gender is wrongly labeled)
# Out:
# gender                              male
# imagequality                        Good
# age                                25-35
# weight                    normal-healthy
# carryingbag     Grocery/Home/Plastic Bag
# footwear                           Fancy
# emotion                          Neutral
# bodypose                  Front-Frontish
# image_path              resized/4865.jpg
# Name: 4864, dtype: object

# %%
# Data set observations:
# 1. all image are of size 224X224
# 2. Majority of image have pictures at the center of the entire images i.e aroud 55 pixel at left and right are black.
# 3. Few image have worng image ofr few category.. at this moment not sure of exact quantites of wrong labelling

# %%
# one hot encoding of labels

one_hot_df = pd.concat([
    df[["image_path"]],
    pd.get_dummies(df.gender, prefix="gender"),
    pd.get_dummies(df.imagequality, prefix="imagequality"),
    pd.get_dummies(df.age, prefix="age"),
    pd.get_dummies(df.weight, prefix="weight"),
    pd.get_dummies(df.carryingbag, prefix="carryingbag"),
    pd.get_dummies(df.footwear, prefix="footwear"),
    pd.get_dummies(df.emotion, prefix="emotion"),
    pd.get_dummies(df.bodypose, prefix="bodypose"),
], axis = 1)

# view one-hot encoding results
one_hot_df.head().T
# Out:
#                                                   0  ...              4
# image_path                            resized/1.jpg  ...  resized/5.jpg
# gender_female                                     0  ...              1
# gender_male                                       1  ...              0
# imagequality_Average                              1  ...              0
# imagequality_Bad                                  0  ...              0
# imagequality_Good                                 0  ...              1
# age_15-25                                         0  ...              0
# age_25-35                                         0  ...              0
# age_35-45                                         1  ...              1
# age_45-55                                         0  ...              0
# age_55+                                           0  ...              0
# weight_normal-healthy                             1  ...              0
# weight_over-weight                                0  ...              0
# weight_slightly-overweight                        0  ...              1
# weight_underweight                                0  ...              0
# carryingbag_Daily/Office/Work Bag                 0  ...              0
# carryingbag_Grocery/Home/Plastic Bag              1  ...              0
# carryingbag_None                                  0  ...              1
# footwear_CantSee                                  0  ...              1
# footwear_Fancy                                    0  ...              0
# footwear_Normal                                   1  ...              0
# emotion_Angry/Serious                             0  ...              0
# emotion_Happy                                     0  ...              0
# emotion_Neutral                                   1  ...              1
# emotion_Sad                                       0  ...              0
# bodypose_Back                                     0  ...              0
# bodypose_Front-Frontish                           1  ...              1
# bodypose_Side                                     0  ...              0
#
# [28 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(one_hot_df, test_size=0.15)
train_df.shape, val_df.shape
# Out:
# ((11537, 28), (2036, 28))

# %%
# Subtracting pixel mean improves accuracy
subtract_pixel_mean = False
batchsize = 128
data_augmentation_flag = False

# %%
if subtract_pixel_mean:
  train_items = train_df.iloc[:]
  train_images = np.stack([cv2.imread(item["image_path"]) for _, item in train_items.iterrows()])
  train_images = train_images.astype('float32') / 255.
  train_images_mean = np.mean(train_images, axis=0)
  del train_images

# %%
import keras
import numpy as np

# Label columns per attribute
_gender_cols_ = [col for col in one_hot_df.columns if col.startswith("gender")]
_imagequality_cols_ = [col for col in one_hot_df.columns if col.startswith("imagequality")]
_age_cols_ = [col for col in one_hot_df.columns if col.startswith("age")]
_weight_cols_ = [col for col in one_hot_df.columns if col.startswith("weight")]
_carryingbag_cols_ = [col for col in one_hot_df.columns if col.startswith("carryingbag")]
_footwear_cols_ = [col for col in one_hot_df.columns if col.startswith("footwear")]
_emotion_cols_ = [col for col in one_hot_df.columns if col.startswith("emotion")]
_bodypose_cols_ = [col for col in one_hot_df.columns if col.startswith("bodypose")]

class PersonDataGenerator(keras.utils.Sequence):
    """Ground truth data generator"""

    
    def __init__(self, df, batch_size=64, shuffle=True, data_augmentation=None):
        self.df = df
        self.batch_size=batch_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.data_augmentation = data_augmentation

    def __len__(self):
        return int(np.floor(self.df.shape[0] / self.batch_size))

    def __getitem__(self, index):
        """fetch batched images and targets"""
        batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
        items = self.df.iloc[batch_slice]
        image = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])

        # normalize the data
        image = image.astype('float32') / 255.

        if subtract_pixel_mean:
          image -= train_images_mean
        
        target = {
            "gender_output": items[_gender_cols_].values,
            "image_quality_output": items[_imagequality_cols_].values,
            "age_output": items[_age_cols_].values,
            "weight_output": items[_weight_cols_].values,
            "bag_output": items[_carryingbag_cols_].values,
            "pose_output": items[_bodypose_cols_].values,
            "footwear_output": items[_footwear_cols_].values,
            "emotion_output": items[_emotion_cols_].values,
        }

        if self.data_augmentation is not None:
            self.data_augmentation.fit(image)
            image = self.data_augmentation.flow(image, shuffle=False, batch_size=self.batch_size).next()

        return image, target

    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        if self.shuffle == True:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

# %%
def cutout_fxn(img):

    height = img.shape[0]
    width = img.shape[1]
    depth = img.shape[2]

    CUT_SIZE = 32 #height//4

    img_new = np.zeros((width+2*CUT_SIZE,height+2*CUT_SIZE, depth), np.float32)

    # take the mean of only center portion.. don't consider black area of eaither side of the image
    # after analysing the few images it is found that actual pictures are
    # at center of the image so cutout to be position accordingly
    # cutout not applie don black region
    offset = 67 # ofset of left and right side of image of balck portion

    mean = np.mean(img[:,offset:-offset:], axis=(0, 1))
    img -= mean

    img_new[CUT_SIZE:width+CUT_SIZE,CUT_SIZE:height+CUT_SIZE,:] = img
    #print(mean)

    mask = np.ones((width+2*CUT_SIZE,height+2*CUT_SIZE,depth), np.float32)
 
    y1 = np.random.randint(height+CUT_SIZE)
    y2 = y1 + CUT_SIZE
    x1 = np.random.randint(offset+CUT_SIZE, width+CUT_SIZE-offset)
    x2 = min(x1 + CUT_SIZE, width+CUT_SIZE-offset)

    mask[y1: y2, x1: x2,:] = 0

    # apply mask
    img_new = img_new * mask

    # denormalize
    img_new += mean

    final_img = img_new[CUT_SIZE:width+CUT_SIZE,CUT_SIZE:height+CUT_SIZE,:]

    return final_img

def lr_schedule(epoch, lr):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after each epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = round(0.0001 * 1/(1 + 0.001 * epoch), 10)
    return lr

# %%
# visualize cutout image here
def view_cutout(imgpath):

  print("====Original image=====\n")
  img = cv2.imread(imgpath)
  cv2_imshow(img)

  print("\n====cutout images=====\n")

  img = img.astype('float32') / 255.
  cutimg = cutout_fxn(img)
  cv2_imshow(cutimg*255)


imgnum = 10
view_cutout(df.image_path.iloc[imgnum])
# Out:
# ====Original image=====
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FCE744D1C18>
# ====cutout images=====
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FCE744D1C88>

# %%
# applying data augmentation
datagen = ImageDataGenerator(
        # randomly flip images
        #horizontal_flip=True,
        zoom_range = 0.20,
        # set function that will be applied on each input
        preprocessing_function=cutout_fxn
    )

# %%
# create train and validation data generators
if data_augmentation_flag:
  print("with image augmentation")
  train_gen = PersonDataGenerator(train_df, batch_size=batchsize, data_augmentation = datagen)
else:
  print("without image augmentation")
  train_gen = PersonDataGenerator(train_df, batch_size=batchsize)

valid_gen = PersonDataGenerator(val_df, batch_size=batchsize, shuffle=False)
# Out:
# without image augmentation

# %%
# get number of output units from data
images, targets = next(iter(train_gen))
num_units = { k.split("_output")[0]:v.shape[1] for k, v in targets.items()}
num_units
# Out:
# {'age': 5,
#  'bag': 3,
#  'emotion': 4,
#  'footwear': 3,
#  'gender': 2,
#  'image_quality': 3,
#  'pose': 3,
#  'weight': 4}

# %%
# viewing augmented image, cutout portion 
if use_google_colab and data_augmentation_flag:
  img_num = 100
  cv2_imshow(images[img_num]*255)

# %%
# viewing augmented image, cutout portion 
if use_google_colab and data_augmentation_flag:
  img_num = 38
  cv2_imshow(images[img_num]*255)

# %% [markdown]
# ### Building CNN Model

# %%
# Define the backbone
dropout_val = 0.20
def create_backbone():
    inputs = Input(shape=(224, 224, 3), name="input")

    # Convolution Block-1
    x = Convolution2D(16, (3, 3), activation='relu', use_bias = False, name="blk1_ly1_conv")(inputs) # OUT: 222X222X16, GRF: 3X3
    x = BatchNormalization(name="blk1_ly1_batchnorm")(x)
    x = Convolution2D(32, (3, 3), activation='relu', use_bias = False, name="blk1_ly2_conv")(x) # OUT: 220X220X32, GRF: 5X5
    x = BatchNormalization(name="blk1_ly2_batchnorm")(x)

    x = MaxPooling2D(pool_size=(2, 2), name="blk1_maxpool")(x) # OUT: 110X110X32, GRF: 6X6
    x = Convolution2D(16, (1, 1), activation='relu', use_bias = False, name="blk1_combine")(x) # OUT: 110X110X16, GRF: 6X6
    x = Dropout(dropout_val, name="blk1_dropout")(x)

    # Convolution Block-2
    x = Convolution2D(32, (3, 3),activation='relu', use_bias = False, name="blk2_ly1_conv")(x) # OUT: 108X208X32, GRF: 10X10
    x = BatchNormalization(name="blk2_ly1_batchnorm")(x)
    x = Convolution2D(32, (3, 3), activation='relu', use_bias = False, name="blk2_ly2_conv")(x) # OUT: 106X206X32, GRF: 14X14
    x = BatchNormalization(name="blk2_ly2_batchnorm")(x)
    x = Convolution2D(32, (3, 3), activation='relu', use_bias = False, name="blk2_ly3_conv")(x) # OUT: 104X204X32, GRF: 18X18
    x = BatchNormalization(name="blk2_ly3_batchnorm")(x)

    x = MaxPooling2D(pool_size=(2, 2), name="blk2_maxpool")(x) # OUT: 52X52X32, GRF: 20X20
    x = Convolution2D(16, (1, 1), activation='relu', use_bias = False, name="blk2_combine")(x) # OUT: 52X52X16, GRF: 20X20
    x = Dropout(dropout_val, name="blk2_dropout")(x)

    # Convolution Block-3
    x = Convolution2D(64, (3, 3), activation='relu', use_bias = False, name="blk3_ly1_conv")(x) # OUT: 50X50X64, GRF: 28X28
    x = BatchNormalization(name="blk3_ly1_batchnorm")(x)
    x = Convolution2D(64, (3, 3), activation='relu', use_bias = False, name="blk3_ly2_conv")(x) # OUT: 48X48X64, GRF: 36X36
    x = BatchNormalization(name="blk3_ly2_batchnorm")(x)
    x = Convolution2D(64, (3, 3), activation='relu', use_bias = False, name="blk3_ly3_conv")(x) # OUT: 46X46X64, GRF: 44X44
    x = BatchNormalization(name="blk3_ly3_batchnorm")(x)

    x = MaxPooling2D(pool_size=(2, 2), name="blk3_maxpool")(x) # OUT: 23X23X64, GRF: 48X48
    x = Convolution2D(16, (1, 1), activation='relu', use_bias = False, name="blk3_combine")(x) # OUT: 23X23X16, GRF: 48X48
    x = Dropout(dropout_val, name="blk3_dropout")(x)

    return inputs, x

# %%
# define model
def create_model():
  minput, backbone = create_backbone()

  def build_tower(name, in_layer):
      neck = Conv2D(num_units[name], (23,23), use_bias = False, name=f"{name}_tower")(in_layer) #1X1Xunits
      neck = Flatten()(neck)
      neck = Dense(128, activation="relu")(neck)
      return neck

  def build_head(name, in_layer):
      return Dense(
          num_units[name], activation="softmax", name=f"{name}_output"
      )(in_layer)

  # heads: 
  gender = build_head("gender", build_tower("gender", backbone))
  image_quality = build_head("image_quality", build_tower("image_quality", backbone))
  age = build_head("age", build_tower("age", backbone))
  weight = build_head("weight", build_tower("weight", backbone))
  bag = build_head("bag", build_tower("bag", backbone))
  footwear = build_head("footwear", build_tower("footwear", backbone))
  emotion = build_head("emotion", build_tower("emotion", backbone))
  pose = build_head("pose", build_tower("pose", backbone))

  model = Model(
      inputs=minput, 
      outputs=[gender, image_quality, age, weight, bag, footwear, pose, emotion]
  )

  return model

# %%
# create model
model = create_model()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
#plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
plot_model(model, to_file='attempt4_model_diagram.png', show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# blk1_ly1_conv (Conv2D)          (None, 222, 222, 16) 432         input[0][0]
# __________________________________________________________________________________________________
# blk1_ly1_batchnorm (BatchNormal (None, 222, 222, 16) 64          blk1_ly1_conv[0][0]
# __________________________________________________________________________________________________
# blk1_ly2_conv (Conv2D)          (None, 220, 220, 32) 4608        blk1_ly1_batchnorm[0][0]
# __________________________________________________________________________________________________
# blk1_ly2_batchnorm (BatchNormal (None, 220, 220, 32) 128         blk1_ly2_conv[0][0]
# __________________________________________________________________________________________________
# blk1_maxpool (MaxPooling2D)     (None, 110, 110, 32) 0           blk1_ly2_batchnorm[0][0]
# __________________________________________________________________________________________________
# blk1_combine (Conv2D)           (None, 110, 110, 16) 512         blk1_maxpool[0][0]
# __________________________________________________________________________________________________
# blk1_dropout (Dropout)          (None, 110, 110, 16) 0           blk1_combine[0][0]
# __________________________________________________________________________________________________
# blk2_ly1_conv (Conv2D)          (None, 108, 108, 32) 4608        blk1_dropout[0][0]
# __________________________________________________________________________________________________
# blk2_ly1_batchnorm (BatchNormal (None, 108, 108, 32) 128         blk2_ly1_conv[0][0]
# __________________________________________________________________________________________________
# blk2_ly2_conv (Conv2D)          (None, 106, 106, 32) 9216        blk2_ly1_batchnorm[0][0]
# __________________________________________________________________________________________________
# blk2_ly2_batchnorm (BatchNormal (None, 106, 106, 32) 128         blk2_ly2_conv[0][0]
# __________________________________________________________________________________________________
# blk2_ly3_conv (Conv2D)          (None, 104, 104, 32) 9216        blk2_ly2_batchnorm[0][0]
# __________________________________________________________________________________________________
# blk2_ly3_batchnorm (BatchNormal (None, 104, 104, 32) 128         blk2_ly3_conv[0][0]
# __________________________________________________________________________________________________
# blk2_maxpool (MaxPooling2D)     (None, 52, 52, 32)   0           blk2_ly3_batchnorm[0][0]
# __________________________________________________________________________________________________
# blk2_combine (Conv2D)           (None, 52, 52, 16)   512         blk2_maxpool[0][0]
# __________________________________________________________________________________________________
# blk2_dropout (Dropout)          (None, 52, 52, 16)   0           blk2_combine[0][0]
# __________________________________________________________________________________________________
# blk3_ly1_conv (Conv2D)          (None, 50, 50, 64)   9216        blk2_dropout[0][0]
# __________________________________________________________________________________________________
# blk3_ly1_batchnorm (BatchNormal (None, 50, 50, 64)   256         blk3_ly1_conv[0][0]
# __________________________________________________________________________________________________
# blk3_ly2_conv (Conv2D)          (None, 48, 48, 64)   36864       blk3_ly1_batchnorm[0][0]
# __________________________________________________________________________________________________
# blk3_ly2_batchnorm (BatchNormal (None, 48, 48, 64)   256         blk3_ly2_conv[0][0]
# __________________________________________________________________________________________________
# blk3_ly3_conv (Conv2D)          (None, 46, 46, 64)   36864       blk3_ly2_batchnorm[0][0]
# __________________________________________________________________________________________________
# blk3_ly3_batchnorm (BatchNormal (None, 46, 46, 64)   256         blk3_ly3_conv[0][0]
# __________________________________________________________________________________________________
# blk3_maxpool (MaxPooling2D)     (None, 23, 23, 64)   0           blk3_ly3_batchnorm[0][0]
# __________________________________________________________________________________________________
# blk3_combine (Conv2D)           (None, 23, 23, 16)   1024        blk3_maxpool[0][0]
# __________________________________________________________________________________________________
# blk3_dropout (Dropout)          (None, 23, 23, 16)   0           blk3_combine[0][0]
# __________________________________________________________________________________________________
# gender_tower (Conv2D)           (None, 1, 1, 2)      16928       blk3_dropout[0][0]
# __________________________________________________________________________________________________
# image_quality_tower (Conv2D)    (None, 1, 1, 3)      25392       blk3_dropout[0][0]
# __________________________________________________________________________________________________
# age_tower (Conv2D)              (None, 1, 1, 5)      42320       blk3_dropout[0][0]
# __________________________________________________________________________________________________
# weight_tower (Conv2D)           (None, 1, 1, 4)      33856       blk3_dropout[0][0]
# __________________________________________________________________________________________________
# bag_tower (Conv2D)              (None, 1, 1, 3)      25392       blk3_dropout[0][0]
# __________________________________________________________________________________________________
# footwear_tower (Conv2D)         (None, 1, 1, 3)      25392       blk3_dropout[0][0]
# __________________________________________________________________________________________________
# pose_tower (Conv2D)             (None, 1, 1, 3)      25392       blk3_dropout[0][0]
# __________________________________________________________________________________________________
# emotion_tower (Conv2D)          (None, 1, 1, 4)      33856       blk3_dropout[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2)            0           gender_tower[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 3)            0           image_quality_tower[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 5)            0           age_tower[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 4)            0           weight_tower[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 3)            0           bag_tower[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 3)            0           footwear_tower[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 3)            0           pose_tower[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 4)            0           emotion_tower[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          384         flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          512         flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          768         flatten_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          640         flatten_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 128)          512         flatten_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 128)          512         flatten_6[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 128)          512         flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 128)          640         flatten_7[0][0]
# __________________________________________________________________________________________________
# gender_output (Dense)           (None, 2)            258         dense_1[0][0]
# __________________________________________________________________________________________________
# image_quality_output (Dense)    (None, 3)            387         dense_2[0][0]
# __________________________________________________________________________________________________
# age_output (Dense)              (None, 5)            645         dense_3[0][0]
# __________________________________________________________________________________________________
# weight_output (Dense)           (None, 4)            516         dense_4[0][0]
# __________________________________________________________________________________________________
# bag_output (Dense)              (None, 3)            387         dense_5[0][0]
# __________________________________________________________________________________________________
# footwear_output (Dense)         (None, 3)            387         dense_6[0][0]
# __________________________________________________________________________________________________
# pose_output (Dense)             (None, 3)            387         dense_8[0][0]
# __________________________________________________________________________________________________
# emotion_output (Dense)          (None, 4)            516         dense_7[0][0]
# ==================================================================================================
# Total params: 350,907
# Trainable params: 350,235
# Non-trainable params: 672
# __________________________________________________________________________________________________

# %%
losses = {
 	"gender_output": "categorical_crossentropy",
 	"image_quality_output": "categorical_crossentropy",
 	"age_output": "categorical_crossentropy",
 	"weight_output": "categorical_crossentropy",
  "bag_output": "categorical_crossentropy",
  "footwear_output": "categorical_crossentropy",
  "pose_output": "categorical_crossentropy",
  "emotion_output": "categorical_crossentropy",
 }

loss_weights = {
 	"gender_output": 1.0,
 	"image_quality_output": 1.0,
 	"age_output": 1.0,
 	"weight_output": 1.0,
  "bag_output": 1.0,
  "footwear_output": 1.0,
  "pose_output": 1.0,
  "emotion_output": 1.0,
 }


opt = SGD(lr=1e-4, momentum=0.9)
model.compile(
    optimizer=opt,
    loss=losses, 
    #loss_weights=loss_weights, 
    metrics=["accuracy"]
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
from keras.callbacks import EarlyStopping

# Prepare model saving directory.
save_dir = os.path.join(os.getcwd(), 'attempt4_cnn1')
#model_name = 'person_model_best.h5'
model_name = 'person_model.{epoch:03d}.h5'

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# using tensorboard callback.
# utility fxn for Initializing Early stopping and Model chekpoint callbacks**
def EarlyStopingModelCheckPoint():
    
    #Adding Early stopping callback to the fit function is going to stop the training,
    #if the val_loss is not going to change even '0.001' for more than 15 continous epochs
    # this help to save training time and not to keep  training if loss does not improve

    early_stopping = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=10)

    #Adding Model Checkpoint callback to the fit function is going to save the weights whenever val_loss achieves 
    # a new low value. Hence saving the best weights occurred during training
    model_checkpoint =  ModelCheckpoint(filepath=filepath,
                                           monitor='val_loss',
                                           verbose=1,
                                           save_best_only=True,
                                           mode='auto',
                                           period=1)
    return early_stopping, model_checkpoint

# %%
# utility fxn for plotting loss and accuracy histroy for model
acc_name_list = ["gender_output_acc", "image_quality_output_acc", "age_output_acc", "weight_output_acc", "bag_output_acc",
                  "footwear_output_acc", "pose_output_acc", "emotion_output_acc"]

def plot_model_history_acc(model_history):
    fig, axs = plt.subplots(1,2,figsize=(20,5))
    # summarize history for accuracy
    legend_list = []
    for acc_name in acc_name_list[:4]:
      val_acc_name = 'val_{}'.format(acc_name)
      axs[0].plot(range(1,len(model_history.history[acc_name])+1),model_history.history[acc_name])
      axs[0].plot(range(1,len(model_history.history[val_acc_name])+1),model_history.history[val_acc_name])

      legend_list.append(acc_name)
      legend_list.append(val_acc_name)

    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history[acc_name])+1),len(model_history.history[acc_name])/10)
    axs[0].legend(legend_list, loc='best')


    legend_list = []
    for acc_name in acc_name_list[4:]:
      val_acc_name = 'val_{}'.format(acc_name)
      axs[1].plot(range(1,len(model_history.history[acc_name])+1),model_history.history[acc_name])
      axs[1].plot(range(1,len(model_history.history[val_acc_name])+1),model_history.history[val_acc_name])

      legend_list.append(acc_name)
      legend_list.append(val_acc_name)

    axs[1].set_title('Model Accuracy')
    axs[1].set_ylabel('Accuracy')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history[acc_name])+1),len(model_history.history[acc_name])/10)
    axs[1].legend(legend_list, loc='best')

def plot_model_history_loss(model_history):
    fig, axs = plt.subplots(1,figsize=(10,5))

    # summarize history for loss
    axs.plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs.plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs.set_title('Model Loss')
    axs.set_ylabel('Loss')
    axs.set_xlabel('Epoch')
    axs.set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs.legend(['train', 'val'], loc='best')
    plt.show()

# %%
from keras.callbacks import *
from keras.optimizers import *

class CyclicLR(Callback):
    """This callback implements a cyclical learning rate policy (CLR).
    The method cycles the learning rate between two boundaries with
    some constant frequency, as detailed in this paper (https://arxiv.org/abs/1506.01186).
    The amplitude of the cycle can be scaled on a per-iteration or 
    per-cycle basis.
    This class has three built-in policies, as put forth in the paper.
    "triangular":
        A basic triangular cycle w/ no amplitude scaling.
    "triangular2":
        A basic triangular cycle that scales initial amplitude by half each cycle.
    "exp_range":
        A cycle that scales initial amplitude by gamma**(cycle iterations) at each 
        cycle iteration.
    For more detail, please see paper.
    
    # Example
        ```python
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., mode='triangular')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```
    
    Class also supports custom scaling functions:
        ```python
            clr_fn = lambda x: 0.5*(1+np.sin(x*np.pi/2.))
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., scale_fn=clr_fn,
                                scale_mode='cycle')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```    
    # Arguments
        base_lr: initial learning rate which is the
            lower boundary in the cycle.
        max_lr: upper boundary in the cycle. Functionally,
            it defines the cycle amplitude (max_lr - base_lr).
            The lr at any cycle is the sum of base_lr
            and some scaling of the amplitude; therefore 
            max_lr may not actually be reached depending on
            scaling function.
        step_size: number of training iterations per
            half cycle. Authors suggest setting step_size
            2-8 x training iterations in epoch.
        mode: one of {triangular, triangular2, exp_range}.
            Default 'triangular'.
            Values correspond to policies detailed above.
            If scale_fn is not None, this argument is ignored.
        gamma: constant in 'exp_range' scaling function:
            gamma**(cycle iterations)
        scale_fn: Custom scaling policy defined by a single
            argument lambda function, where 
            0 <= scale_fn(x) <= 1 for all x >= 0.
            mode paramater is ignored 
        scale_mode: {'cycle', 'iterations'}.
            Defines whether scale_fn is evaluated on 
            cycle number or cycle iterations (training
            iterations since start of cycle). Default is 'cycle'.
    """

    def __init__(self, base_lr=0.001, max_lr=0.006, step_size=2000., mode='triangular',
                 gamma=1., scale_fn=None, scale_mode='cycle'):
        super(CyclicLR, self).__init__()

        self.base_lr = base_lr
        self.max_lr = max_lr
        self.step_size = step_size
        self.mode = mode
        self.gamma = gamma
        if scale_fn == None:
            if self.mode == 'triangular':
                self.scale_fn = lambda x: 1.
                self.scale_mode = 'cycle'
            elif self.mode == 'triangular2':
                self.scale_fn = lambda x: 1/(2.**(x-1))
                self.scale_mode = 'cycle'
            elif self.mode == 'exp_range':
                self.scale_fn = lambda x: gamma**(x)
                self.scale_mode = 'iterations'
        else:
            self.scale_fn = scale_fn
            self.scale_mode = scale_mode
        self.clr_iterations = 0.
        self.trn_iterations = 0.
        self.history = {}

        self._reset()

    def _reset(self, new_base_lr=None, new_max_lr=None,
               new_step_size=None):
        """Resets cycle iterations.
        Optional boundary/step size adjustment.
        """
        if new_base_lr != None:
            self.base_lr = new_base_lr
        if new_max_lr != None:
            self.max_lr = new_max_lr
        if new_step_size != None:
            self.step_size = new_step_size
        self.clr_iterations = 0.
        
    def clr(self):
        cycle = np.floor(1+self.clr_iterations/(2*self.step_size))
        x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1)
        if self.scale_mode == 'cycle':
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(cycle)
        else:
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(self.clr_iterations)
        
    def on_train_begin(self, logs={}):
        logs = logs or {}

        if self.clr_iterations == 0:
            K.set_value(self.model.optimizer.lr, self.base_lr)
        else:
            K.set_value(self.model.optimizer.lr, self.clr())        
            
    def on_batch_end(self, epoch, logs=None):
        
        logs = logs or {}
        self.trn_iterations += 1
        self.clr_iterations += 1

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.trn_iterations)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        
        K.set_value(self.model.optimizer.lr, self.clr())

# %%
# Prepare callback for cyclic LR
step_size= 8 * (train_df.shape[0] // batchsize)
MIN_LR = 1e-6
MAX_LR = 1e-3

#Triangular policy
clr_triangular = CyclicLR(mode='triangular', base_lr=MIN_LR, max_lr=MAX_LR, step_size=step_size)

clr_triangular2 = CyclicLR(mode='triangular2', base_lr=MIN_LR, max_lr=MAX_LR, step_size=step_size)

# Exponential policy
#clr_exp = CyclicLR(mode='exp_range', gamma=0.99994, base_lr=MIN_LR, max_lr=MAX_LR, step_size=step_size)
clr_exp = CyclicLR(mode='exp_range', gamma=0.99994, base_lr=MIN_LR, max_lr=MAX_LR, step_size=step_size)

#CLR - Custom Sinusoidal Cycle-Policy
clr_scale_fxn = lambda x: 0.5*(1+np.sin(x*np.pi/2.))
clr_sine = CyclicLR(scale_fn=clr_scale_fxn, scale_mode='cycle', base_lr=MIN_LR, max_lr=MAX_LR, step_size=step_size )

clr_used = clr_exp

# %%
print("step_size: ", step_size)
print("batchsize: ", batchsize)
# Out:
# step_size:  720
# batchsize:  128

# %%
# Prepare callbacks for model saving and for learning rate adjustment.

early_stopping, model_checkpoint = EarlyStopingModelCheckPoint()

lr_scheduler = LearningRateScheduler(lr_schedule, verbose=1)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=2, #patience=5
                               min_lr=0.1e-7)

callbacks = [early_stopping, model_checkpoint, clr_used]

# %%
history = model.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    use_multiprocessing=True,
    workers=6, 
    epochs=96,
    verbose=1, 
    callbacks=callbacks
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/96
# 89/90 [============================>.] - ETA: 0s - loss: 9.1589 - gender_output_loss: 0.7113 - image_quality_output_loss: 1.0789 - age_output_loss: 1.5415 - weight_output_loss: 1.2424 - bag_output_loss: 1.0856 - footwear_output_loss: 1.1216 - pose_output_loss: 0.9753 - emotion_output_loss: 1.4023 - gender_output_acc: 0.4915 - image_quality_output_acc: 0.3983 - age_output_acc: 0.3284 - weight_output_acc: 0.4492 - bag_output_acc: 0.3658 - footwear_output_acc: 0.3880 - pose_output_acc: 0.5948 - emotion_output_acc: 0.3379
.6874 - val_image_quality_output_loss: 0.9938 - val_age_output_loss: 1.4367 - val_weight_output_loss: 1.0024 - val_bag_output_loss: 0.9333 - val_footwear_output_loss: 0.9893 - val_pose_output_loss: 0.9400 - val_emotion_output_loss: 0.9487 - val_gender_output_acc: 0.5531 - val_image_quality_output_acc: 0.5385 - val_age_output_acc: 0.4031 - val_weight_output_acc: 0.6542 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.5380 - val_pose_output_acc: 0.6224 - val_emotion_output_acc: 0.7083
#
# Epoch 00003: val_loss improved from 8.07044 to 7.93155, saving model to /content/attempt4_cnn1/person_model.003.h5
# Epoch 4/96
# 90/90 [==============================] - 35s 394ms/step - loss: 7.8182 - gender_output_loss: 0.6827 - image_quality_output_loss: 0.9655 - age_output_loss: 1.4363 - weight_output_loss: 0.9964 - bag_output_loss: 0.9228 - footwear_output_loss: 0.9701 - pose_output_loss: 0.9288 - emotion_output_loss: 0.9156 - gender_output_acc: 0.5653 - image_quality_output_acc: 0.5560 - age_output_acc: 0.3931 - weight_output_acc: 0.6324 - bag_output_acc: 0.5629 - footwear_output_acc: 0.5439 - pose_output_acc: 0.6169 - emotion_output_acc: 0.7116 - val_loss: 7.8993 - val_gender_output_loss: 0.6836 - val_image_quality_output_loss: 0.9780 - val_age_output_loss: 1.4455 - val_weight_output_loss: 0.9958 - val_bag_output_loss: 0.9431 - val_footwear_output_loss: 0.9806 - val_pose_output_loss: 0.9391 - val_emotion_output_loss: 0.9335 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.5385 - val_age_output_acc: 0.4010 - val_weight_output_acc: 0.6542 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.5490 - val_pose_output_acc: 0.6224 - val_emotion_output_acc: 0.7083
#
# Epoch 00004: val_loss improved from 7.93155 to 7.89926, saving model to /content/attempt4_cnn1/person_model.004.h5
# Epoch 5/96
# 90/90 [==============================] - 35s 390ms/step - loss: 7.7403 - gender_output_loss: 0.6737 - image_quality_output_loss: 0.9401 - age_output_loss: 1.4271 - weight_output_loss: 0.9907 - bag_output_loss: 0.9196 - footwear_output_loss: 0.9538 - pose_output_loss: 0.9252 - emotion_output_loss: 0.9101 - gender_output_acc: 0.5778 - image_quality_output_acc: 0.5560 - age_output_acc: 0.3955 - weight_output_acc: 0.6322 - bag_output_acc: 0.5635 - footwear_output_acc: 0.5577 - pose_output_acc: 0.6173 - emotion_output_acc: 0.7120 - val_loss: 7.7649 - val_gender_output_loss: 0.6710 - val_image_quality_output_loss: 0.9658 - val_age_output_loss: 1.4273 - val_weight_output_loss: 0.9892 - val_bag_output_loss: 0.9231 - val_footwear_output_loss: 0.9614 - val_pose_output_loss: 0.9148 - val_emotion_output_loss: 0.9122 - val_gender_output_acc: 0.5677 - val_image_quality_output_acc: 0.5448 - val_age_output_acc: 0.4010 - val_weight_output_acc: 0.6542 - val_bag_output_acc: 0.5594 - val_footwear_output_acc: 0.5510 - val_pose_output_acc: 0.6224 - val_emotion_output_acc: 0.7083
#
# Epoch 00005: val_loss improved from 7.89926 to 7.76490, saving model to /content/attempt4_cnn1/person_model.005.h5
#
# Epoch 00021: val_loss did not improve from 7.18164
# Epoch 22/96
# 90/90 [==============================] - 37s 406ms/step - loss: 7.0194 - gender_output_loss: 0.5317 - image_quality_output_loss: 0.8791 - age_output_loss: 1.3711 - weight_output_loss: 0.9561 - bag_output_loss: 0.8673 - footwear_output_loss: 0.8401 - pose_output_loss: 0.6974 - emotion_output_loss: 0.8767 - gender_output_acc: 0.7283 - image_quality_output_acc: 0.5778 - age_output_acc: 0.4062 - weight_output_acc: 0.6332 - bag_output_acc: 0.5931 - footwear_output_acc: 0.6187 - pose_output_acc: 0.6992 - emotion_output_acc: 0.7114 - val_loss: 7.1721 - val_gender_output_loss: 0.5633 - val_image_quality_output_loss: 0.9523 - val_age_output_loss: 1.3912 - val_weight_output_loss: 0.9333 - val_bag_output_loss: 0.8851 - val_footwear_output_loss: 0.8520 - val_pose_output_loss: 0.6919 - val_emotion_output_loss: 0.9031 - val_gender_output_acc: 0.7063 - val_image_quality_output_acc: 0.5380 - val_age_output_acc: 0.4042 - val_weight_output_acc: 0.6521 - val_bag_output_acc: 0.5766 - val_footwear_output_acc: 0.6135 - val_pose_output_acc: 0.7172 - val_emotion_output_acc: 0.7083
#
# Epoch 00022: val_loss improved from 7.18164 to 7.17210, saving model to /content/attempt4_cnn1/person_model.022.h5
# Epoch 23/96
# 90/90 [==============================] - 36s 398ms/step - loss: 6.9978 - gender_output_loss: 0.5290 - image_quality_output_loss: 0.8805 - age_output_loss: 1.3685 - weight_output_loss: 0.9565 - bag_output_loss: 0.8648 - footwear_output_loss: 0.8361 - pose_output_loss: 0.6872 - emotion_output_loss: 0.8752 - gender_output_acc: 0.7350 - image_quality_output_acc: 0.5730 - age_output_acc: 0.4021 - weight_output_acc: 0.6325 - bag_output_acc: 0.5939 - footwear_output_acc: 0.6241 - pose_output_acc: 0.7058 - emotion_output_acc: 0.7120 - val_loss: 7.2257 - val_gender_output_loss: 0.5574 - val_image_quality_output_loss: 0.9822 - val_age_output_loss: 1.3857 - val_weight_output_loss: 0.9431 - val_bag_output_loss: 0.8849 - val_footwear_output_loss: 0.8446 - val_pose_output_loss: 0.7145 - val_emotion_output_loss: 0.9133 - val_gender_output_acc: 0.7141 - val_image_quality_output_acc: 0.5099 - val_age_output_acc: 0.4005 - val_weight_output_acc: 0.6516 - val_bag_output_acc: 0.5802 - val_footwear_output_acc: 0.6182 - val_pose_output_acc: 0.6948 - val_emotion_output_acc: 0.7078
#
# Epoch 00023: val_loss did not improve from 7.17210
# Epoch 24/96
# 90/90 [==============================] - 36s 401ms/step - loss: 6.9681 - gender_output_loss: 0.5205 - image_quality_output_loss: 0.8766 - age_output_loss: 1.3683 - weight_output_loss: 0.9557 - bag_output_loss: 0.8607 - footwear_output_loss: 0.8311 - pose_output_loss: 0.6796 - emotion_output_loss: 0.8758 - gender_output_acc: 0.7352 - image_quality_output_acc: 0.5799 - age_output_acc: 0.4031 - weight_output_acc: 0.6336 - bag_output_acc: 0.5951 - footwear_output_acc: 0.6284 - pose_output_acc: 0.7123 - emotion_output_acc: 0.7119 - val_loss: 7.1346 - val_gender_output_loss: 0.5477 - val_image_quality_output_loss: 0.9401 - val_age_output_loss: 1.3877 - val_weight_output_loss: 0.9340 - val_bag_output_loss: 0.8871 - val_footwear_output_loss: 0.8428 - val_pose_output_loss: 0.6928 - val_emotion_output_loss: 0.9024 - val_gender_output_acc: 0.7193 - val_image_quality_output_acc: 0.5500 - val_age_output_acc: 0.3964 - val_weight_output_acc: 0.6536 - val_bag_output_acc: 0.5839 - val_footwear_output_acc: 0.6214 - val_pose_output_acc: 0.7026 - val_emotion_output_acc: 0.7089
#
# Epoch 00024: val_loss improved from 7.17210 to 7.13463, saving model to /content/attempt4_cnn1/person_model.024.h5
# Epoch 25/96
# 89/90 [============================>.] - ETA: 0s - loss: 6.9210 - gender_output_loss: 0.5098 - image_quality_output_loss: 0.8728 - age_output_loss: 1.3621 - weight_output_loss: 0.9508 - bag_output_loss: 0.8567 - footwear_output_loss: 0.8283 - pose_output_loss: 0.6718 - emotion_output_loss: 0.8686 - gender_output_acc: 0.7463 - image_quality_output_acc: 0.5792 - age_output_acc: 0.4101 - weight_output_acc: 0.6340 - bag_output_acc: 0.5976 - footwear_output_acc: 0.6303 - pose_output_acc: 0.7154 - emotion_output_acc: 0.7128
# Epoch 00024: val_loss improved from 7.17210 to 7.13463, saving model to /content/attempt4_cnn1/person_model.024.h5
# 90/90 [==============================] - 35s 394ms/step - loss: 6.9248 - gender_output_loss: 0.5094 - image_quality_output_loss: 0.8724 - age_output_loss: 1.3619 - weight_output_loss: 0.9516 - bag_output_loss: 0.8578 - footwear_output_loss: 0.8284 - pose_output_loss: 0.6733 - emotion_output_loss: 0.8699 - gender_output_acc: 0.7464 - image_quality_output_acc: 0.5799 - age_output_acc: 0.4107 - weight_output_acc: 0.6335 - bag_output_acc: 0.5969 - footwear_output_acc: 0.6303 - pose_output_acc: 0.7148 - emotion_output_acc: 0.7123 - val_loss: 7.1231 - val_gender_output_loss: 0.5457 - val_image_quality_output_loss: 0.9449 - val_age_output_loss: 1.3903 - val_weight_output_loss: 0.9440 - val_bag_output_loss: 0.8871 - val_footwear_output_loss: 0.8325 - val_pose_output_loss: 0.6803 - val_emotion_output_loss: 0.8984 - val_gender_output_acc: 0.7167 - val_image_quality_output_acc: 0.5495 - val_age_output_acc: 0.3995 - val_weight_output_acc: 0.6495 - val_bag_output_acc: 0.5875 - val_footwear_output_acc: 0.6250 - val_pose_output_acc: 0.7214 - val_emotion_output_acc: 0.7089
#
# Epoch 00025: val_loss improved from 7.13463 to 7.12309, saving model to /content/attempt4_cnn1/person_model.025.h5
# Epoch 26/96
 - val_image_quality_output_loss: 0.9930 - val_age_output_loss: 1.3852 - val_weight_output_loss: 0.9379 - val_bag_output_loss: 0.8784 - val_footwear_output_loss: 0.8387 - val_pose_output_loss: 0.6815 - val_emotion_output_loss: 0.9124 - val_gender_output_acc: 0.7333 - val_image_quality_output_acc: 0.5146 - val_age_output_acc: 0.3937 - val_weight_output_acc: 0.6531 - val_bag_output_acc: 0.5828 - val_footwear_output_acc: 0.6167 - val_pose_output_acc: 0.7099 - val_emotion_output_acc: 0.7042
#
# Epoch 00027: val_loss did not improve from 7.10863
# Epoch 28/96
# 90/90 [==============================] - 36s 397ms/step - loss: 6.7990 - gender_output_loss: 0.4862 - image_quality_output_loss: 0.8635 - age_output_loss: 1.3477 - weight_output_loss: 0.9371 - bag_output_loss: 0.8446 - footwear_output_loss: 0.8132 - pose_output_loss: 0.6471 - emotion_output_loss: 0.8596 - gender_output_acc: 0.7631 - image_quality_output_acc: 0.5867 - age_output_acc: 0.4117 - weight_output_acc: 0.6360 - bag_output_acc: 0.6137 - footwear_output_acc: 0.6366 - pose_output_acc: 0.7262 - emotion_output_acc: 0.7122 - val_loss: 7.0949 - val_gender_output_loss: 0.5242 - val_image_quality_output_loss: 0.9513 - val_age_output_loss: 1.3781 - val_weight_output_loss: 0.9456 - val_bag_output_loss: 0.8867 - val_footwear_output_loss: 0.8307 - val_pose_output_loss: 0.6750 - val_emotion_output_loss: 0.9032 - val_gender_output_acc: 0.7286 - val_image_quality_output_acc: 0.5339 - val_age_output_acc: 0.4052 - val_weight_output_acc: 0.6479 - val_bag_output_acc: 0.5891 - val_footwear_output_acc: 0.6255 - val_pose_output_acc: 0.7167 - val_emotion_output_acc: 0.7083
#
# Epoch 00028: val_loss improved from 7.10863 to 7.09491, saving model to /content/attempt4_cnn1/person_model.028.h5
# Epoch 29/96
# 90/90 [==============================] - 35s 392ms/step - loss: 6.7571 - gender_output_loss: 0.4746 - image_quality_output_loss: 0.8584 - age_output_loss: 1.3433 - weight_output_loss: 0.9382 - bag_output_loss: 0.8395 - footwear_output_loss: 0.8097 - pose_output_loss: 0.6364 - emotion_output_loss: 0.8570 - gender_output_acc: 0.7677 - image_quality_output_acc: 0.5894 - age_output_acc: 0.4130 - weight_output_acc: 0.6349 - bag_output_acc: 0.6129 - footwear_output_acc: 0.6341 - pose_output_acc: 0.7298 - emotion_output_acc: 0.7135 - val_loss: 7.1090 - val_gender_output_loss: 0.5224 - val_image_quality_output_loss: 0.9857 - val_age_output_loss: 1.3771 - val_weight_output_loss: 0.9469 - val_bag_output_loss: 0.8736 - val_footwear_output_loss: 0.8269 - val_pose_output_loss: 0.6743 - val_emotion_output_loss: 0.9021 - val_gender_output_acc: 0.7453 - val_image_quality_output_acc: 0.5323 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.6500 - val_bag_output_acc: 0.5927 - val_footwear_output_acc: 0.6177 - val_pose_output_acc: 0.7198 - val_emotion_output_acc: 0.7078
#
# Epoch 00029: val_loss did not improve from 7.09491
# Epoch 30/96
# 90/90 [==============================] - 36s 401ms/step - loss: 6.7329 - gender_output_loss: 0.4730 - image_quality_output_loss: 0.8577 - age_output_loss: 1.3408 - weight_output_loss: 0.9324 - bag_output_loss: 0.8353 - footwear_output_loss: 0.8070 - pose_output_loss: 0.6298 - emotion_output_loss: 0.8568 - gender_output_acc: 0.7697 - image_quality_output_acc: 0.5918 - age_output_acc: 0.4155 - weight_output_acc: 0.6359 - bag_output_acc: 0.6185 - footwear_output_acc: 0.6379 - pose_output_acc: 0.7391 - emotion_output_acc: 0.7125 - val_loss: 7.0583 - val_gender_output_loss: 0.5174 - val_image_quality_output_loss: 0.9357 - val_age_output_loss: 1.3799 - val_weight_output_loss: 0.9444 - val_bag_output_loss: 0.8926 - val_footwear_output_loss: 0.8217 - val_pose_output_loss: 0.6615 - val_emotion_output_loss: 0.9051 - val_gender_output_acc: 0.7432 - val_image_quality_output_acc: 0.5484 - val_age_output_acc: 0.3948 - val_weight_output_acc: 0.6500 - val_bag_output_acc: 0.5906 - val_footwear_output_acc: 0.6219 - val_pose_output_acc: 0.7266 - val_emotion_output_acc: 0.7083
#
# Epoch 00030: val_loss improved from 7.09491 to 7.05825, saving model to /content/attempt4_cnn1/person_model.030.h5
# Epoch 31/96
# 90/90 [==============================] - 35s 392ms/step - loss: 6.6970 - gender_output_loss: 0.4649 - image_quality_output_loss: 0.8563 - age_output_loss: 1.3374 - weight_output_loss: 0.9301 - bag_output_loss: 0.8320 - footwear_output_loss: 0.8003 - pose_output_loss: 0.6242 - emotion_output_loss: 0.8518 - gender_output_acc: 0.7760 - image_quality_output_acc: 0.5916 - age_output_acc: 0.4143 - weight_output_acc: 0.6364 - bag_output_acc: 0.6182 - footwear_output_acc: 0.6413 - pose_output_acc: 0.7401 - emotion_output_acc: 0.7124 - val_loss: 7.0693 - val_gender_output_loss: 0.5210 - val_image_quality_output_loss: 0.9554 - val_age_output_loss: 1.3767 - val_weight_output_loss: 0.9417 - val_bag_output_loss: 0.8762 - val_footwear_output_loss: 0.8274 - val_pose_output_loss: 0.6665 - val_emotion_output_loss: 0.9044 - val_gender_output_acc: 0.7443 - val_image_quality_output_acc: 0.5292 - val_age_output_acc: 0.3969 - val_weight_output_acc: 0.6469 - val_bag_output_acc: 0.5891 - val_footwear_output_acc: 0.6208 - val_pose_output_acc: 0.7271 - val_emotion_output_acc: 0.7078
#
# Epoch 00031: val_loss did not improve from 7.05825
# Epoch 32/96
# 90/90 [==============================] - 36s 398ms/step - loss: 6.6787 - gender_output_loss: 0.4586 - image_quality_output_loss: 0.8550 - age_output_loss: 1.3325 - weight_output_loss: 0.9288 - bag_output_loss: 0.8323 - footwear_output_loss: 0.8012 - pose_output_loss: 0.6188 - emotion_output_loss: 0.8514 - gender_output_acc: 0.7791 - image_quality_output_acc: 0.5921 - age_output_acc: 0.4193 - weight_output_acc: 0.6362 - bag_output_acc: 0.6189 - footwear_output_acc: 0.6379 - pose_output_
#
# Epoch 00046: val_loss did not improve from 7.00296
# Epoch 47/96
# 90/90 [==============================] - 36s 396ms/step - loss: 6.3341 - gender_output_loss: 0.4042 - image_quality_output_loss: 0.8241 - age_output_loss: 1.2866 - weight_output_loss: 0.8942 - bag_output_loss: 0.7909 - footwear_output_loss: 0.7580 - pose_output_loss: 0.5570 - emotion_output_loss: 0.8190 - gender_output_acc: 0.8168 - image_quality_output_acc: 0.6112 - age_output_acc: 0.4385 - weight_output_acc: 0.6444 - bag_output_acc: 0.6490 - footwear_output_acc: 0.6608 - pose_output_acc: 0.7755 - emotion_output_acc: 0.7176 - val_loss: 7.0326 - val_gender_output_loss: 0.4845 - val_image_quality_output_loss: 0.9753 - val_age_output_loss: 1.3781 - val_weight_output_loss: 0.9420 - val_bag_output_loss: 0.8707 - val_footwear_output_loss: 0.8245 - val_pose_output_loss: 0.6488 - val_emotion_output_loss: 0.9088 - val_gender_output_acc: 0.7641 - val_image_quality_output_acc: 0.5302 - val_age_output_acc: 0.4000 - val_weight_output_acc: 0.6458 - val_bag_output_acc: 0.6016 - val_footwear_output_acc: 0.6292 - val_pose_output_acc: 0.7401 - val_emotion_output_acc: 0.7031
#
# Epoch 00047: val_loss did not improve from 7.00296
# Epoch 48/96
# 90/90 [==============================] - 36s 395ms/step - loss: 6.3094 - gender_output_loss: 0.3984 - image_quality_output_loss: 0.8222 - age_output_loss: 1.2840 - weight_output_loss: 0.8912 - bag_output_loss: 0.7900 - footwear_output_loss: 0.7525 - pose_output_loss: 0.5528 - emotion_output_loss: 0.8184 - gender_output_acc: 0.8176 - image_quality_output_acc: 0.6150 - age_output_acc: 0.4359 - weight_output_acc: 0.6424 - bag_output_acc: 0.6471 - footwear_output_acc: 0.6618 - pose_output_acc: 0.7755 - emotion_output_acc: 0.7171 - val_loss: 7.0431 - val_gender_output_loss: 0.4876 - val_image_quality_output_loss: 0.9712 - val_age_output_loss: 1.3755 - val_weight_output_loss: 0.9433 - val_bag_output_loss: 0.8766 - val_footwear_output_loss: 0.8234 - val_pose_output_loss: 0.6550 - val_emotion_output_loss: 0.9105 - val_gender_output_acc: 0.7635 - val_image_quality_output_acc: 0.5271 - val_age_output_acc: 0.4000 - val_weight_output_acc: 0.6443 - val_bag_output_acc: 0.5922 - val_footwear_output_acc: 0.6292 - val_pose_output_acc: 0.7401 - val_emotion_output_acc: 0.7010
#
# Epoch 00048: val_loss did not improve from 7.00296
# Epoch 49/96
# 89/90 [============================>.] - ETA: 0s - loss: 6.2936 - gender_output_loss: 0.3964 - image_quality_output_loss: 0.8170 - age_output_loss: 1.2845 - weight_output_loss: 0.8874 - bag_output_loss: 0.7896 - footwear_output_loss: 0.7552 - pose_output_loss: 0.5491 - emotion_output_loss: 0.8144 - gender_output_acc: 0.8215 - image_quality_output_acc: 0.6182 - age_output_acc: 0.4348 - weight_output_acc: 0.6441 - bag_output_acc: 0.6466 - footwear_output_acc: 0.6634 - pose_output_acc: 0.7807 - emotion_output_acc: 0.7188
#
# Epoch 00054: val_loss did not improve from 7.00296
# Epoch 55/96
# 89/90 [============================>.] - ETA: 0s - loss: 6.2825 - gender_output_loss: 0.4006 - image_quality_output_loss: 0.8169 - age_output_loss: 1.2813 - weight_output_loss: 0.8855 - bag_output_loss: 0.7866 - footwear_output_loss: 0.7514 - pose_output_loss: 0.5503 - emotion_output_loss: 0.8100 - gender_output_acc: 0.8198 - image_quality_output_acc: 0.6184 - age_output_acc: 0.4439 - weight_output_acc: 0.6442 - bag_output_acc: 0.6507 - footwear_output_acc: 0.6645 - pose_output_acc: 0.7738 - emotion_output_acc: 0.7186
# Epoch 00054: val_loss did not improve from 7.00296
# Epoch 55/96
# 90/90 [==============================] - 36s 400ms/step - loss: 6.2846 - gender_output_loss: 0.3999 - image_quality_output_loss: 0.8172 - age_output_loss: 1.2816 - weight_output_loss: 0.8854 - bag_output_loss: 0.7870 - footwear_output_loss: 0.7525 - pose_output_loss: 0.5504 - emotion_output_loss: 0.8107 - gender_output_acc: 0.8199 - image_quality_output_acc: 0.6180 - age_output_acc: 0.4443 - weight_output_acc: 0.6441 - bag_output_acc: 0.6503 - footwear_output_acc: 0.6635 - pose_output_acc: 0.7739 - emotion_output_acc: 0.7183 - val_loss: 7.0808 - val_gender_output_loss: 0.4895 - val_image_quality_output_loss: 0.9433 - val_age_output_loss: 1.3925 - val_weight_output_loss: 0.9523 - val_bag_output_loss: 0.9047 - val_footwear_output_loss: 0.8312 - val_pose_output_loss: 0.6497 - val_emotion_output_loss: 0.9177 - val_gender_output_acc: 0.7693 - val_image_quality_output_acc: 0.5406 - val_age_output_acc: 0.3786 - val_weight_output_acc: 0.6401 - val_bag_output_acc: 0.5979 - val_footwear_output_acc: 0.6182 - val_pose_output_acc: 0.7370 - val_emotion_output_acc: 0.7010
#
# Epoch 00055: val_loss did not improve from 7.00296

# %%
# view how LR has worked
plt.xlabel('Training Iterations')
plt.ylabel('Learning Rate')
plt.title("CLR - 'Exponential' Policy")
plt.plot(clr_used.history['iterations'], clr_used.history['lr'])

# %%
plot_model_history_loss(history)

# %%
plot_model_history_acc(history)

# %%
# Load best saved model
from keras.models import load_model
best_model = load_model("/content/attempt4_cnn1/person_model.045.h5")

# %%
# Evaluate Model for test data
results = best_model.evaluate_generator(valid_gen, verbose=1)
results_dict = dict(zip(best_model.metrics_names, results))
# Out:
# 15/15 [==============================] - 3s 188ms/step

# %%
# get accuracies for each category
acc_results = {name:result for name, result in zip(best_model.metrics_names, results) if name.endswith("acc")}
print("Total Validation Loss: ", results_dict['loss'])
print("Validation Accuracies: ")
acc_results
# Out:
# Total Validation Loss:  7.0029646555582685
# Validation Accuracies:
# {'age_output_acc': 0.39895833333333336,
#  'bag_output_acc': 0.6,
#  'emotion_output_acc': 0.7078125,
#  'footwear_output_acc': 0.6244791666666667,
#  'gender_output_acc': 0.7598958333333333,
#  'image_quality_output_acc': 0.5375,
#  'pose_output_acc': 0.7317708333333334,
#  'weight_output_acc': 0.6484375}
