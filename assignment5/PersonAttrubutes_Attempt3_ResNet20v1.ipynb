# %%
use_google_colab = True

# %%
# mount gdrive
if use_google_colab:
    from google.colab import drive
    drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# unzip data
if use_google_colab:
    # !unzip -q "/content/gdrive/My Drive/TSAI/session5/hvc_data.zip"
    # look for `hvc_annotations.csv` file and `resized` dir
    # %ls
# Out:
# gdrive/  hvc_annotations.csv  resized/  sample_data/

# %%
if use_google_colab:
  # %tensorflow_version 1.x

import cv2
import json

import numpy as np
import pandas as pd
import os

from functools import partial
from pathlib import Path 
from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

from keras.applications import VGG16

from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.layers import GlobalAveragePooling2D, Dropout, MaxPooling2D
from keras.models import Model
from keras.optimizers import Adam
from keras.optimizers import SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2

from keras.preprocessing import image
from keras.utils.vis_utils import plot_model

from keras import backend as K

import matplotlib.pyplot as plt
# %matplotlib inline

if use_google_colab:
    from google.colab.patches import cv2_imshow
# Out:
# Using TensorFlow backend.

# %%
# load annotations
df = pd.read_csv("hvc_annotations.csv")
del df["filename"] # remove unwanted column

print("Shape: ", df.shape)
df.head(3)
# Out:
# Shape:  (13573, 9)
#    gender imagequality    age  ...        emotion        bodypose     image_path
# 0    male      Average  35-45  ...        Neutral  Front-Frontish  resized/1.jpg
# 1  female      Average  35-45  ...  Angry/Serious  Front-Frontish  resized/2.jpg
# 2    male         Good  45-55  ...        Neutral  Front-Frontish  resized/3.jpg
#
# [3 rows x 9 columns]

# %%
# visualize few images
fig = plt.figure(figsize=(8,3))
for i in range(10):
  ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
  img = image.load_img(df.image_path[i])
  plt.imshow(img)
plt.show()

# %%
# utility function to view image properties and its labeling
def viewData(index):
  img = image.load_img(df.image_path[index])
  plt.imshow(img)
  print(df.iloc[index])

# %%
viewData(4864) # typical case of wrong labeling (Gender is wrongly labeled)
# Out:
# gender                              male
# imagequality                        Good
# age                                25-35
# weight                    normal-healthy
# carryingbag     Grocery/Home/Plastic Bag
# footwear                           Fancy
# emotion                          Neutral
# bodypose                  Front-Frontish
# image_path              resized/4865.jpg
# Name: 4864, dtype: object

# %%
# Data set observations:
# 1. all image are of size 224X224
# 2. Majority of image have pictures at the center of the entire images i.e aroud 55 pixel at left and right are black.
# 3. Few image have worng image ofr few category.. at this moment not sure of exact quantites of wrong labelling

# %%
# one hot encoding of labels

one_hot_df = pd.concat([
    df[["image_path"]],
    pd.get_dummies(df.gender, prefix="gender"),
    pd.get_dummies(df.imagequality, prefix="imagequality"),
    pd.get_dummies(df.age, prefix="age"),
    pd.get_dummies(df.weight, prefix="weight"),
    pd.get_dummies(df.carryingbag, prefix="carryingbag"),
    pd.get_dummies(df.footwear, prefix="footwear"),
    pd.get_dummies(df.emotion, prefix="emotion"),
    pd.get_dummies(df.bodypose, prefix="bodypose"),
], axis = 1)

# view one-hot encoding results
one_hot_df.head().T
# Out:
#                                                   0  ...              4
# image_path                            resized/1.jpg  ...  resized/5.jpg
# gender_female                                     0  ...              1
# gender_male                                       1  ...              0
# imagequality_Average                              1  ...              0
# imagequality_Bad                                  0  ...              0
# imagequality_Good                                 0  ...              1
# age_15-25                                         0  ...              0
# age_25-35                                         0  ...              0
# age_35-45                                         1  ...              1
# age_45-55                                         0  ...              0
# age_55+                                           0  ...              0
# weight_normal-healthy                             1  ...              0
# weight_over-weight                                0  ...              0
# weight_slightly-overweight                        0  ...              1
# weight_underweight                                0  ...              0
# carryingbag_Daily/Office/Work Bag                 0  ...              0
# carryingbag_Grocery/Home/Plastic Bag              1  ...              0
# carryingbag_None                                  0  ...              1
# footwear_CantSee                                  0  ...              1
# footwear_Fancy                                    0  ...              0
# footwear_Normal                                   1  ...              0
# emotion_Angry/Serious                             0  ...              0
# emotion_Happy                                     0  ...              0
# emotion_Neutral                                   1  ...              1
# emotion_Sad                                       0  ...              0
# bodypose_Back                                     0  ...              0
# bodypose_Front-Frontish                           1  ...              1
# bodypose_Side                                     0  ...              0
#
# [28 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(one_hot_df, test_size=0.15)
train_df.shape, val_df.shape
# Out:
# ((11537, 28), (2036, 28))

# %%
# Subtracting pixel mean improves accuracy
subtract_pixel_mean = False
batchsize = 64
data_augmentation_flag = True

# %%
if subtract_pixel_mean:
  train_items = train_df.iloc[:]
  train_images = np.stack([cv2.imread(item["image_path"]) for _, item in train_items.iterrows()])
  train_images = train_images.astype('float32') / 255
  train_images_mean = np.mean(train_images, axis=0)
  del train_images

# %%
import keras
import numpy as np

# Label columns per attribute
_gender_cols_ = [col for col in one_hot_df.columns if col.startswith("gender")]
_imagequality_cols_ = [col for col in one_hot_df.columns if col.startswith("imagequality")]
_age_cols_ = [col for col in one_hot_df.columns if col.startswith("age")]
_weight_cols_ = [col for col in one_hot_df.columns if col.startswith("weight")]
_carryingbag_cols_ = [col for col in one_hot_df.columns if col.startswith("carryingbag")]
_footwear_cols_ = [col for col in one_hot_df.columns if col.startswith("footwear")]
_emotion_cols_ = [col for col in one_hot_df.columns if col.startswith("emotion")]
_bodypose_cols_ = [col for col in one_hot_df.columns if col.startswith("bodypose")]

class PersonDataGenerator(keras.utils.Sequence):
    """Ground truth data generator"""

    
    def __init__(self, df, batch_size=64, shuffle=True, data_augmentation=None):
        self.df = df
        self.batch_size=batch_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.data_augmentation = data_augmentation

    def __len__(self):
        return int(np.floor(self.df.shape[0] / self.batch_size))

    def __getitem__(self, index):
        """fetch batched images and targets"""
        batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
        items = self.df.iloc[batch_slice]
        image = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])

        # normalize the data
        image = image.astype('float32') / 255.

        if subtract_pixel_mean:
          image -= train_images_mean
        
        target = {
            "gender_output": items[_gender_cols_].values,
            "image_quality_output": items[_imagequality_cols_].values,
            "age_output": items[_age_cols_].values,
            "weight_output": items[_weight_cols_].values,
            "bag_output": items[_carryingbag_cols_].values,
            "pose_output": items[_bodypose_cols_].values,
            "footwear_output": items[_footwear_cols_].values,
            "emotion_output": items[_emotion_cols_].values,
        }

        if self.data_augmentation is not None:
            self.data_augmentation.fit(image)
            image = self.data_augmentation.flow(image, shuffle=False, batch_size=self.batch_size).next()

        return image, target

    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        if self.shuffle == True:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

# %%
def cutout_fxn(img):

    height = img.shape[0]
    width = img.shape[1]
    depth = img.shape[2]

    CUT_SIZE = 32 #height//4

    img_new = np.zeros((width+2*CUT_SIZE,height+2*CUT_SIZE, depth), np.float32)

    # take the mean of only center portion.. don't consider black area of eaither side of the image
    # after analysing the few images it is found that actual pictures are
    # at center of the image so cutout to be position accordingly
    # cutout not applie don black region
    offset = 67 # ofset of left and right side of image of balck portion

    mean = np.mean(img[:,offset:-offset:], axis=(0, 1))
    img -= mean

    img_new[CUT_SIZE:width+CUT_SIZE,CUT_SIZE:height+CUT_SIZE,:] = img
    #print(mean)

    mask = np.ones((width+2*CUT_SIZE,height+2*CUT_SIZE,depth), np.float32)
 
    y1 = np.random.randint(height+CUT_SIZE)
    y2 = y1 + CUT_SIZE
    x1 = np.random.randint(offset+CUT_SIZE, width+CUT_SIZE-offset)
    x2 = min(x1 + CUT_SIZE, width+CUT_SIZE-offset)

    mask[y1: y2, x1: x2,:] = 0

    # apply mask
    img_new = img_new * mask

    # denormalize
    img_new += mean

    final_img = img_new[CUT_SIZE:width+CUT_SIZE,CUT_SIZE:height+CUT_SIZE,:]

    return final_img

def lr_schedule(epoch, lr):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after each epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = round(0.0001 * 1/(1 + 0.001 * epoch), 10)
    return lr

# %%
# visualize cutout image here
def view_cutout(imgpath):

  print("====Original image=====\n")
  img = cv2.imread(imgpath)
  cv2_imshow(img)

  print("\n====cutout images=====\n")

  img = img.astype('float32') / 255.
  cutimg = cutout_fxn(img)
  cv2_imshow(cutimg*255)


imgnum = 10
view_cutout(df.image_path.iloc[imgnum])
# Out:
# ====Original image=====
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FA95228D978>
# ====cutout images=====
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FA95228D898>

# %%
# applying data augmentation
datagen = ImageDataGenerator(
        # randomly flip images
        #horizontal_flip=True,
        #zoom_range = 0.20,
        # set function that will be applied on each input
        preprocessing_function=cutout_fxn
    )

# %%
# create train and validation data generators
if data_augmentation_flag:
  print("with image augmentation")
  train_gen = PersonDataGenerator(train_df, batch_size=batchsize, data_augmentation = datagen)
else:
  print("without image augmentation")
  train_gen = PersonDataGenerator(train_df, batch_size=batchsize)

valid_gen = PersonDataGenerator(val_df, batch_size=batchsize, shuffle=False)
# Out:
# with image augmentation

# %%
# get number of output units from data
images, targets = next(iter(train_gen))
num_units = { k.split("_output")[0]:v.shape[1] for k, v in targets.items()}
num_units
# Out:
# {'age': 5,
#  'bag': 3,
#  'emotion': 4,
#  'footwear': 3,
#  'gender': 2,
#  'image_quality': 3,
#  'pose': 3,
#  'weight': 4}

# %%
# viewing augmented image, cutout portion 
img_num = 10
if use_google_colab and data_augmentation_flag:
    cv2_imshow(images[img_num]*255)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FA9522AE278>

# %%
# viewing augmented image, cutout portion 
img_num = 20
if use_google_colab and data_augmentation_flag:
    cv2_imshow(images[img_num]*255)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FA9522AE3C8>

# %% [markdown]
# ### Building ResNet Model

# %%
n = 3

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 1

dropout_val = 0.20

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)
print("model_type: ",model_type)
# Out:
# model_type:  ResNet20v1

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=False,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

"""For this assignment, Features maps sizes as below:
    stage 0: 224x224, 16
    stage 1: 112X112, 32
    stage 2: 56X56, 48

    Each stage with 3 block and each block with 2 convolutions.
    Hence total of stages(3) * blocks(3) * convlayer(2) + 2 = 20 layer.
"""
def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 8n+2 (eg 20, 32, 44 in [a])')

    # Start model definition.
    num_filters = 16 # increase filter size
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape, name="input")
    #x = resnet_layer(inputs=inputs) # old code
    x = resnet_layer(inputs=inputs, num_filters=num_filters)
    # Instantiate the stack of residual units
    for stack in range(3): # numof stage is modified to 4
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample

            if(strides == 2):
              # replaced 3X3 with Stride=2 by MaxPool and 1X1 kernel
              y = MaxPooling2D(pool_size=(2,2))(x)
              y = resnet_layer(inputs=y,
                               num_filters=num_filters,
                               kernel_size=1)
              y = Dropout(dropout_val)(y)
            else:
              y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims                
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
                #x = Dropout(0.05)(x) # added dropout
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters = num_filters+16

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    #x = AveragePooling2D(pool_size=28)(x) 
    return inputs, x

# %%
# define model
def create_model():
  
  minput, backbone = resnet_v1(input_shape=(224,224,3), depth=depth)

  def build_tower(name, in_layer):
      neck = Dropout(dropout_val)(in_layer)
      neck = Conv2D(num_units[name], (56,56), use_bias = False)(neck) #1X1Xunits
      neck = Flatten()(neck)
      neck = Dropout(dropout_val)(neck)
      neck = Dense(128, activation="relu")(neck)
      return neck

  def build_head(name, in_layer):
      return Dense(
          num_units[name], activation="softmax", name=f"{name}_output"
      )(in_layer)

  # heads: 
  gender = build_head("gender", build_tower("gender", backbone))
  image_quality = build_head("image_quality", build_tower("image_quality", backbone))
  age = build_head("age", build_tower("age", backbone))
  weight = build_head("weight", build_tower("weight", backbone))
  bag = build_head("bag", build_tower("bag", backbone))
  footwear = build_head("footwear", build_tower("footwear", backbone))
  emotion = build_head("emotion", build_tower("emotion", backbone))
  pose = build_head("pose", build_tower("pose", backbone))

  model = Model(
      inputs=minput, 
      outputs=[gender, image_quality, age, weight, bag, footwear, pose, emotion]
  )

  return model

# %%
# create model
model = create_model()

# %%
#plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
plot_model(model, to_file='model_plot.png', show_layer_names=True)

# %%
print(model_type)
model.summary()
# Out:
# ResNet20v1
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 224, 224, 16) 448         input[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 224, 224, 16) 0           conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 224, 224, 16) 2320        activation_63[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 224, 224, 16) 0           conv2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 224, 224, 16) 2320        activation_64[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 224, 224, 16) 0           activation_63[0][0]
#                                                                  conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 224, 224, 16) 0           add_31[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 224, 224, 16) 2320        activation_65[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 224, 224, 16) 0           conv2d_86[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 224, 224, 16) 2320        activation_66[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 224, 224, 16) 0           activation_65[0][0]
#                                                                  conv2d_87[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 224, 224, 16) 0           add_32[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 224, 224, 16) 2320        activation_67[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 224, 224, 16) 0           conv2d_88[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 224, 224, 16) 2320        activation_68[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 224, 224, 16) 0           activation_67[0][0]
#                                                                  conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 224, 224, 16) 0           add_33[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 112, 112, 16) 0           activation_69[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 112, 112, 32) 544         max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 112, 112, 32) 0           conv2d_90[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 112, 112, 32) 0           activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 112, 112, 32) 544         activation_69[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 112, 112, 32) 9248        dropout_27[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 112, 112, 32) 0           conv2d_92[0][0]
#                                                                  conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 112, 112, 32) 0           add_34[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 112, 112, 32) 9248        activation_71[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 112, 112, 32) 0           conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 112, 112, 32) 9248        activation_72[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 112, 112, 32) 0           activation_71[0][0]
#                                                                  conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 112, 112, 32) 0           add_35[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 112, 112, 32) 9248        activation_73[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 112, 112, 32) 0           conv2d_95[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 112, 112, 32) 9248        activation_74[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 112, 112, 32) 0           activation_73[0][0]
#                                                                  conv2d_96[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 112, 112, 32) 0           add_36[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 56, 56, 32)   0           activation_75[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 56, 56, 48)   1584        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 56, 56, 48)   0           conv2d_97[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 56, 56, 48)   0           activation_76[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 56, 56, 48)   1584        activation_75[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 56, 56, 48)   20784       dropout_28[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 56, 56, 48)   0           conv2d_99[0][0]
#                                                                  conv2d_98[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 56, 56, 48)   0           add_37[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 56, 56, 48)   20784       activation_77[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 56, 56, 48)   0           conv2d_100[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 56, 56, 48)   20784       activation_78[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 56, 56, 48)   0           activation_77[0][0]
#                                                                  conv2d_101[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 56, 56, 48)   0           add_38[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 56, 56, 48)   20784       activation_79[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 56, 56, 48)   0           conv2d_102[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 56, 56, 48)   20784       activation_80[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 56, 56, 48)   0           activation_79[0][0]
#                                                                  conv2d_103[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 56, 56, 48)   0           add_39[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 56, 56, 48)   0           activation_81[0][0]
# __________________________________________________________________________________________________
# dropout_31 (Dropout)            (None, 56, 56, 48)   0           activation_81[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 56, 56, 48)   0           activation_81[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 56, 56, 48)   0           activation_81[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 56, 56, 48)   0           activation_81[0][0]
# __________________________________________________________________________________________________
# dropout_39 (Dropout)            (None, 56, 56, 48)   0           activation_81[0][0]
# __________________________________________________________________________________________________
# dropout_43 (Dropout)            (None, 56, 56, 48)   0           activation_81[0][0]
# __________________________________________________________________________________________________
# dropout_41 (Dropout)            (None, 56, 56, 48)   0           activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 1, 1, 2)      301056      dropout_29[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 1, 1, 3)      451584      dropout_31[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 1, 1, 5)      752640      dropout_33[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 1, 1, 4)      602112      dropout_35[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 1, 1, 3)      451584      dropout_37[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 1, 1, 3)      451584      dropout_39[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 1, 1, 3)      451584      dropout_43[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 1, 1, 4)      602112      dropout_41[0][0]
# __________________________________________________________________________________________________
# flatten_17 (Flatten)            (None, 2)            0           conv2d_104[0][0]
# __________________________________________________________________________________________________
# flatten_18 (Flatten)            (None, 3)            0           conv2d_105[0][0]
# __________________________________________________________________________________________________
# flatten_19 (Flatten)            (None, 5)            0           conv2d_106[0][0]
# __________________________________________________________________________________________________
# flatten_20 (Flatten)            (None, 4)            0           conv2d_107[0][0]
# __________________________________________________________________________________________________
# flatten_21 (Flatten)            (None, 3)            0           conv2d_108[0][0]
# __________________________________________________________________________________________________
# flatten_22 (Flatten)            (None, 3)            0           conv2d_109[0][0]
# __________________________________________________________________________________________________
# flatten_24 (Flatten)            (None, 3)            0           conv2d_111[0][0]
# __________________________________________________________________________________________________
# flatten_23 (Flatten)            (None, 4)            0           conv2d_110[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 2)            0           flatten_17[0][0]
# __________________________________________________________________________________________________
# dropout_32 (Dropout)            (None, 3)            0           flatten_18[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 5)            0           flatten_19[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 4)            0           flatten_20[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 3)            0           flatten_21[0][0]
# __________________________________________________________________________________________________
# dropout_40 (Dropout)            (None, 3)            0           flatten_22[0][0]
# __________________________________________________________________________________________________
# dropout_44 (Dropout)            (None, 3)            0           flatten_24[0][0]
# __________________________________________________________________________________________________
# dropout_42 (Dropout)            (None, 4)            0           flatten_23[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 128)          384         dropout_30[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 128)          512         dropout_32[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 128)          768         dropout_34[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 128)          640         dropout_36[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 128)          512         dropout_38[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 128)          512         dropout_40[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 128)          512         dropout_44[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 128)          640         dropout_42[0][0]
# __________________________________________________________________________________________________
# gender_output (Dense)           (None, 2)            258         dense_17[0][0]
# __________________________________________________________________________________________________
# image_quality_output (Dense)    (None, 3)            387         dense_18[0][0]
# __________________________________________________________________________________________________
# age_output (Dense)              (None, 5)            645         dense_19[0][0]
# __________________________________________________________________________________________________
# weight_output (Dense)           (None, 4)            516         dense_20[0][0]
# __________________________________________________________________________________________________
# bag_output (Dense)              (None, 3)            387         dense_21[0][0]
# __________________________________________________________________________________________________
# footwear_output (Dense)         (None, 3)            387         dense_22[0][0]
# __________________________________________________________________________________________________
# pose_output (Dense)             (None, 3)            387         dense_24[0][0]
# __________________________________________________________________________________________________
# emotion_output (Dense)          (None, 4)            516         dense_23[0][0]
# ==================================================================================================
# Total params: 4,241,003
# Trainable params: 4,241,003
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
losses = {
 	"gender_output": "categorical_crossentropy",
 	"image_quality_output": "categorical_crossentropy",
 	"age_output": "categorical_crossentropy",
 	"weight_output": "categorical_crossentropy",
  "bag_output": "categorical_crossentropy",
  "footwear_output": "categorical_crossentropy",
  "pose_output": "categorical_crossentropy",
  "emotion_output": "categorical_crossentropy",
 }

loss_weights = {
 	"gender_output": 1.0,
 	"image_quality_output": 1.0,
 	"age_output": 1.0,
 	"weight_output": 1.0,
  "bag_output": 1.0,
  "footwear_output": 1.0,
  "pose_output": 1.0,
  "emotion_output": 1.0,
 }


opt = SGD(lr=1e-4, momentum=0.9)
model.compile(
    optimizer=opt,
    loss=losses, 
    #loss_weights=loss_weights, 
    metrics=["accuracy"]
)

# %%
from keras.callbacks import EarlyStopping

# Prepare model saving directory.
save_dir = os.path.join(os.getcwd(), 'attempt3_resnet5')
#model_name = 'person_model_best.h5'
model_name = 'person_model.{epoch:03d}.h5'

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# using tensorboard callback.
# utility fxn for Initializing Early stopping and Model chekpoint callbacks**
def EarlyStopingModelCheckPoint():
    
    #Adding Early stopping callback to the fit function is going to stop the training,
    #if the val_loss is not going to change even '0.001' for more than 15 continous epochs
    # this help to save training time and not to keep  training if loss does not improve

    early_stopping = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=10)

    #Adding Model Checkpoint callback to the fit function is going to save the weights whenever val_loss achieves 
    # a new low value. Hence saving the best weights occurred during training
    model_checkpoint =  ModelCheckpoint(filepath=filepath,
                                           monitor='val_loss',
                                           verbose=1,
                                           save_best_only=True,
                                           mode='auto',
                                           period=1)
    return early_stopping, model_checkpoint

# %%
from keras.callbacks import *
from keras.optimizers import *

class CyclicLR(Callback):
    """This callback implements a cyclical learning rate policy (CLR).
    The method cycles the learning rate between two boundaries with
    some constant frequency, as detailed in this paper (https://arxiv.org/abs/1506.01186).
    The amplitude of the cycle can be scaled on a per-iteration or 
    per-cycle basis.
    This class has three built-in policies, as put forth in the paper.
    "triangular":
        A basic triangular cycle w/ no amplitude scaling.
    "triangular2":
        A basic triangular cycle that scales initial amplitude by half each cycle.
    "exp_range":
        A cycle that scales initial amplitude by gamma**(cycle iterations) at each 
        cycle iteration.
    For more detail, please see paper.
    
    # Example
        ```python
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., mode='triangular')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```
    
    Class also supports custom scaling functions:
        ```python
            clr_fn = lambda x: 0.5*(1+np.sin(x*np.pi/2.))
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., scale_fn=clr_fn,
                                scale_mode='cycle')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```    
    # Arguments
        base_lr: initial learning rate which is the
            lower boundary in the cycle.
        max_lr: upper boundary in the cycle. Functionally,
            it defines the cycle amplitude (max_lr - base_lr).
            The lr at any cycle is the sum of base_lr
            and some scaling of the amplitude; therefore 
            max_lr may not actually be reached depending on
            scaling function.
        step_size: number of training iterations per
            half cycle. Authors suggest setting step_size
            2-8 x training iterations in epoch.
        mode: one of {triangular, triangular2, exp_range}.
            Default 'triangular'.
            Values correspond to policies detailed above.
            If scale_fn is not None, this argument is ignored.
        gamma: constant in 'exp_range' scaling function:
            gamma**(cycle iterations)
        scale_fn: Custom scaling policy defined by a single
            argument lambda function, where 
            0 <= scale_fn(x) <= 1 for all x >= 0.
            mode paramater is ignored 
        scale_mode: {'cycle', 'iterations'}.
            Defines whether scale_fn is evaluated on 
            cycle number or cycle iterations (training
            iterations since start of cycle). Default is 'cycle'.
    """

    def __init__(self, base_lr=0.001, max_lr=0.006, step_size=2000., mode='triangular',
                 gamma=1., scale_fn=None, scale_mode='cycle'):
        super(CyclicLR, self).__init__()

        self.base_lr = base_lr
        self.max_lr = max_lr
        self.step_size = step_size
        self.mode = mode
        self.gamma = gamma
        if scale_fn == None:
            if self.mode == 'triangular':
                self.scale_fn = lambda x: 1.
                self.scale_mode = 'cycle'
            elif self.mode == 'triangular2':
                self.scale_fn = lambda x: 1/(2.**(x-1))
                self.scale_mode = 'cycle'
            elif self.mode == 'exp_range':
                self.scale_fn = lambda x: gamma**(x)
                self.scale_mode = 'iterations'
        else:
            self.scale_fn = scale_fn
            self.scale_mode = scale_mode
        self.clr_iterations = 0.
        self.trn_iterations = 0.
        self.history = {}

        self._reset()

    def _reset(self, new_base_lr=None, new_max_lr=None,
               new_step_size=None):
        """Resets cycle iterations.
        Optional boundary/step size adjustment.
        """
        if new_base_lr != None:
            self.base_lr = new_base_lr
        if new_max_lr != None:
            self.max_lr = new_max_lr
        if new_step_size != None:
            self.step_size = new_step_size
        self.clr_iterations = 0.
        
    def clr(self):
        cycle = np.floor(1+self.clr_iterations/(2*self.step_size))
        x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1)
        if self.scale_mode == 'cycle':
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(cycle)
        else:
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(self.clr_iterations)
        
    def on_train_begin(self, logs={}):
        logs = logs or {}

        if self.clr_iterations == 0:
            K.set_value(self.model.optimizer.lr, self.base_lr)
        else:
            K.set_value(self.model.optimizer.lr, self.clr())        
            
    def on_batch_end(self, epoch, logs=None):
        
        logs = logs or {}
        self.trn_iterations += 1
        self.clr_iterations += 1

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.trn_iterations)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        
        K.set_value(self.model.optimizer.lr, self.clr())

# %%
acc_name_list = ["gender_output_acc", "image_quality_output_acc", "age_output_acc", "weight_output_acc", "bag_output_acc",
                  "footwear_output_acc", "pose_output_acc", "emotion_output_acc"]

def plot_model_history_acc(model_history):
    fig, axs = plt.subplots(1,2,figsize=(20,5))
    # summarize history for accuracy
    legend_list = []
    for acc_name in acc_name_list[:4]:
      val_acc_name = 'val_{}'.format(acc_name)
      axs[0].plot(range(1,len(model_history.history[acc_name])+1),model_history.history[acc_name])
      axs[0].plot(range(1,len(model_history.history[val_acc_name])+1),model_history.history[val_acc_name])

      legend_list.append(acc_name)
      legend_list.append(val_acc_name)

    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history[acc_name])+1),len(model_history.history[acc_name])/10)
    axs[0].legend(legend_list, loc='best')


    legend_list = []
    for acc_name in acc_name_list[4:]:
      val_acc_name = 'val_{}'.format(acc_name)
      axs[1].plot(range(1,len(model_history.history[acc_name])+1),model_history.history[acc_name])
      axs[1].plot(range(1,len(model_history.history[val_acc_name])+1),model_history.history[val_acc_name])

      legend_list.append(acc_name)
      legend_list.append(val_acc_name)

    axs[1].set_title('Model Accuracy')
    axs[1].set_ylabel('Accuracy')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history[acc_name])+1),len(model_history.history[acc_name])/10)
    axs[1].legend(legend_list, loc='best')

def plot_model_history_loss(model_history):
    fig, axs = plt.subplots(1,figsize=(10,5))

    # summarize history for loss
    axs.plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs.plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs.set_title('Model Loss')
    axs.set_ylabel('Loss')
    axs.set_xlabel('Epoch')
    axs.set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs.legend(['train', 'val'], loc='best')
    plt.show()

# %%
# Prepare callback for cyclic LR
step_size= 8 * (train_df.shape[0] // batchsize)
#MIN_LR = 1e-6
#MAX_LR = 1e-3

MIN_LR = 1e-7
MAX_LR = 1e-3

#Triangular policy
clr_triangular = CyclicLR(mode='triangular', base_lr=MIN_LR, max_lr=MAX_LR, step_size=step_size)

clr_triangular2 = CyclicLR(mode='triangular2', base_lr=MIN_LR, max_lr=MAX_LR, step_size=step_size)

# Exponential policy
#clr_exp = CyclicLR(mode='exp_range', gamma=0.99994, base_lr=MIN_LR, max_lr=MAX_LR, step_size=step_size)
clr_exp = CyclicLR(mode='exp_range', gamma=0.99994, base_lr=MIN_LR, max_lr=MAX_LR, step_size=step_size)

#CLR - Custom Sinusoidal Cycle-Policy
clr_scale_fxn = lambda x: 0.5*(1+np.sin(x*np.pi/2.))
clr_sine = CyclicLR(scale_fn=clr_scale_fxn, scale_mode='cycle', base_lr=MIN_LR, max_lr=MAX_LR, step_size=step_size )

clr_used = clr_exp

# %%
print("step_size: ", step_size)
print("batchsize: ", batchsize)
# Out:
# step_size:  1440
# batchsize:  64

# %%
# Prepare callbacks for model saving and for learning rate adjustment.

early_stopping, model_checkpoint = EarlyStopingModelCheckPoint()

lr_scheduler = LearningRateScheduler(lr_schedule, verbose=1)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=2, #patience=5
                               min_lr=0.1e-7)

callbacks = [early_stopping, model_checkpoint, clr_used]

# %%
history = model.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    use_multiprocessing=True,
    workers=6, 
    epochs=96,
    verbose=1, 
    callbacks=callbacks
)
# Out:
# Epoch 1/96
# 179/180 [============================>.] - ETA: 0s - loss: 9.9704 - gender_output_loss: 0.7049 - image_quality_output_loss: 1.2010 - age_output_loss: 1.9047 - weight_output_loss: 1.5634 - bag_output_loss: 1.0367 - footwear_output_loss: 1.1138 - pose_output_loss: 1.0177 - emotion_output_loss: 1.2947 - gender_output_acc: 0.5459 - image_quality_output_acc: 0.5000 - age_output_acc: 0.3010 - weight_output_acc: 0.4808 - bag_output_acc: 0.5164 - footwear_output_acc: 0.5033 - pose_output_acc: 0.5865 - emotion_output_acc: 0.5973
#
# 180/180 [==============================] - 69s 381ms/step - loss: 9.9587 - gender_output_loss: 0.7049 - image_quality_output_loss: 1.1992 - age_output_loss: 1.9022 - weight_output_loss: 1.5606 - bag_output_loss: 1.0358 - footwear_output_loss: 1.1126 - pose_output_loss: 1.0173 - emotion_output_loss: 1.2926 - gender_output_acc: 0.5458 - image_quality_output_acc: 0.5013 - age_output_acc: 0.3019 - weight_output_acc: 0.4817 - bag_output_acc: 0.5171 - footwear_output_acc: 0.5042 - pose_output_acc: 0.5864 - emotion_output_acc: 0.5980 - val_loss: 8.0998 - val_gender_output_loss: 0.6830 - val_image_quality_output_loss: 0.9841 - val_age_output_loss: 1.4342 - val_weight_output_loss: 1.0282 - val_bag_output_loss: 0.9445 - val_footwear_output_loss: 0.9613 - val_pose_output_loss: 0.9424 - val_emotion_output_loss: 0.9886 - val_gender_output_acc: 0.5685 - val_image_quality_output_acc: 0.5615 - val_age_output_acc: 0.4047 - val_weight_output_acc: 0.6351 - val_bag_output_acc: 0.5469 - val_footwear_output_acc: 0.5635 - val_pose_output_acc: 0.6366 - val_emotion_output_acc: 0.7107
#
# Epoch 00001: val_loss improved from inf to 8.09981, saving model to /content/attempt3_resnet5/person_model.001.h5
# Epoch 2/96
# 180/180 [==============================] - 63s 348ms/step - loss: 8.1444 - gender_output_loss: 0.6809 - image_quality_output_loss: 0.9957 - age_output_loss: 1.4722 - weight_output_loss: 1.0398 - bag_output_loss: 0.9345 - footwear_output_loss: 0.9699 - pose_output_loss: 0.9437 - emotion_output_loss: 0.9742 - gender_output_acc: 0.5622 - image_quality_output_acc: 0.5417 - age_output_acc: 0.3674 - weight_output_acc: 0.6278 - bag_output_acc: 0.5648 - footwear_output_acc: 0.5390 - pose_output_acc: 0.6016 - emotion_output_acc: 0.7019 - val_loss: 8.0169 - val_gender_output_loss: 0.6753 - val_image_quality_output_loss: 0.9717 - val_age_output_loss: 1.4452 - val_weight_output_loss: 1.0174 - val_bag_output_loss: 0.9457 - val_footwear_output_loss: 0.9346 - val_pose_output_loss: 0.9430 - val_emotion_output_loss: 0.9506 - val_gender_output_acc: 0.5721 - val_image_quality_output_acc: 0.5600 - val_age_output_acc: 0.3730 - val_weight_output_acc: 0.6351 - val_bag_output_acc: 0.5469 - val_footwear_output_acc: 0.5766 - val_pose_output_acc: 0.6366 - val_emotion_output_acc: 0.7107
#
# Epoch 00002: val_loss improved from 8.09981 to 8.01687, saving model to /content/attempt3_resnet5/person_model.002.h5
# Epoch 3/96
#
# Epoch 00005: val_loss improved from 7.79781 to 7.65393, saving model to /content/attempt3_resnet5/person_model.005.h5
# Epoch 6/96
# 179/180 [============================>.] - ETA: 0s - loss: 7.5912 - gender_output_loss: 0.6030 - image_quality_output_loss: 0.9396 - age_output_loss: 1.4015 - weight_output_loss: 0.9805 - bag_output_loss: 0.9018 - footwear_output_loss: 0.8750 - pose_output_loss: 0.8452 - emotion_output_loss: 0.9115 - gender_output_acc: 0.6677 - image_quality_output_acc: 0.5553 - age_output_acc: 0.3955 - weight_output_acc: 0.6352 - bag_output_acc: 0.5665 - footwear_output_acc: 0.6043 - pose_output_acc: 0.6204 - emotion_output_acc: 0.7113
# 180/180 [==============================] - 63s 350ms/step - loss: 7.5912 - gender_output_loss: 0.6034 - image_quality_output_loss: 0.9398 - age_output_loss: 1.4010 - weight_output_loss: 0.9800 - bag_output_loss: 0.9022 - footwear_output_loss: 0.8752 - pose_output_loss: 0.8453 - emotion_output_loss: 0.9112 - gender_output_acc: 0.6672 - image_quality_output_acc: 0.5552 - age_output_acc: 0.3962 - weight_output_acc: 0.6355 - bag_output_acc: 0.5663 - footwear_output_acc: 0.6043 - pose_output_acc: 0.6206 - emotion_output_acc: 0.7114 - val_loss: 7.5852 - val_gender_output_loss: 0.6049 - val_image_quality_output_loss: 0.9323 - val_age_output_loss: 1.3898 - val_weight_output_loss: 1.0119 - val_bag_output_loss: 0.9169 - val_footwear_output_loss: 0.8596 - val_pose_output_loss: 0.8078 - val_emotion_output_loss: 0.9289 - val_gender_output_acc: 0.6734 - val_image_quality_output_acc: 0.5645 - val_age_output_acc: 0.4032 - val_weight_output_acc: 0.6351 - val_bag_output_acc: 0.5539 - val_footwear_output_acc: 0.6210 - val_pose_output_acc: 0.6442 - val_emotion_output_acc: 0.7107
#
# Epoch 00006: val_loss improved from 7.65393 to 7.58521, saving model to /content/attempt3_resnet5/person_model.006.h5
# Epoch 7/96
# 179/180 [============================>.] - ETA: 0s - loss: 7.4658 - gender_output_loss: 0.5828 - image_quality_output_loss: 0.9254 - age_output_loss: 1.3926 - weight_output_loss: 0.9723 - bag_output_loss: 0.8934 - footwear_output_loss: 0.8562 - pose_output_loss: 0.8142 - emotion_output_loss: 0.8958 - gender_output_acc: 0.6868 - image_quality_output_acc: 0.5580 - age_output_acc: 0.4035 - weight_output_acc: 0.6361 - bag_output_acc: 0.5687 - footwear_output_acc: 0.6108 - pose_output_acc: 0.6463 - emotion_output_acc: 0.7117
# Epoch 00006: val_loss improved from 7.65393 to 7.58521, saving model to /content/attempt3_resnet5/person_model.006.h5
#
# Epoch 00011: val_loss did not improve from 7.42904
# Epoch 12/96
# 180/180 [==============================] - 63s 352ms/step - loss: 6.2705 - gender_output_loss: 0.4358 - image_quality_output_loss: 0.8219 - age_output_loss: 1.2037 - weight_output_loss: 0.8628 - bag_output_loss: 0.7409 - footwear_output_loss: 0.6944 - pose_output_loss: 0.5765 - emotion_output_loss: 0.8013 - gender_output_acc: 0.7960 - image_quality_output_acc: 0.6085 - age_output_acc: 0.4881 - weight_output_acc: 0.6530 - bag_output_acc: 0.6601 - footwear_output_acc: 0.6912 - pose_output_acc: 0.7576 - emotion_output_acc: 0.7143 - val_loss: 7.6275 - val_gender_output_loss: 0.5971 - val_image_quality_output_loss: 0.9431 - val_age_output_loss: 1.4488 - val_weight_output_loss: 1.0019 - val_bag_output_loss: 0.9578 - val_footwear_output_loss: 0.8927 - val_pose_output_loss: 0.7137 - val_emotion_output_loss: 0.9392 - val_gender_output_acc: 0.7082 - val_image_quality_output_acc: 0.5509 - val_age_output_acc: 0.3674 - val_weight_output_acc: 0.6265 - val_bag_output_acc: 0.5811 - val_footwear_output_acc: 0.6280 - val_pose_output_acc: 0.7056 - val_emotion_output_acc: 0.7077
#
# Epoch 00012: val_loss did not improve from 7.42904
# Epoch 13/96
# 180/180 [==============================] - 63s 349ms/step - loss: 5.8025 - gender_output_loss: 0.3965 - image_quality_output_loss: 0.7618 - age_output_loss: 1.1214 - weight_output_loss: 0.8107 - bag_output_loss: 0.6760 - footwear_output_loss: 0.6409 - pose_output_loss: 0.5062 - emotion_output_loss: 0.7556 - gender_output_acc: 0.8105 - image_quality_output_acc: 0.6441 - age_output_acc: 0.5253 - weight_output_acc: 0.6724 - bag_output_acc: 0.6972 - footwear_output_acc: 0.7209 - pose_output_acc: 0.7911 - emotion_output_acc: 0.7221 - val_loss: 7.8993 - val_gender_output_loss: 0.6293 - val_image_quality_output_loss: 0.9683 - val_age_output_loss: 1.4943 - val_weight_output_loss: 1.0329 - val_bag_output_loss: 0.9873 - val_footwear_output_loss: 0.9256 - val_pose_output_loss: 0.7582 - val_emotion_output_loss: 0.9698 - val_gender_output_acc: 0.6961 - val_image_quality_output_acc: 0.5081 - val_age_output_acc: 0.3614 - val_weight_output_acc: 0.5827 - val_bag_output_acc: 0.5539 - val_footwear_output_acc: 0.6139 - val_pose_output_acc: 0.7051 - val_emotion_output_acc: 0.7011
#
# Epoch 13/96
#
# Epoch 00013: val_loss did not improve from 7.42904
# Epoch 14/96
#
# Epoch 00016: val_loss did not improve from 7.42904
# Epoch 17/96
# 180/180 [==============================] - 63s 351ms/step - loss: 3.9650 - gender_output_loss: 0.2418 - image_quality_output_loss: 0.5333 - age_output_loss: 0.7828 - weight_output_loss: 0.5731 - bag_output_loss: 0.4572 - footwear_output_loss: 0.4188 - pose_output_loss: 0.3168 - emotion_output_loss: 0.5076 - gender_output_acc: 0.8931 - image_quality_output_acc: 0.7669 - age_output_acc: 0.6876 - weight_output_acc: 0.7618 - bag_output_acc: 0.8008 - footwear_output_acc: 0.8253 - pose_output_acc: 0.8747 - emotion_output_acc: 0.8063 - val_loss: 9.7435 - val_gender_output_loss: 0.8082 - val_image_quality_output_loss: 1.1914 - val_age_output_loss: 1.8674 - val_weight_output_loss: 1.2081 - val_bag_output_loss: 1.2442 - val_footwear_output_loss: 1.1659 - val_pose_output_loss: 0.9253 - val_emotion_output_loss: 1.1994 - val_gender_output_acc: 0.7001 - val_image_quality_output_acc: 0.4808 - val_age_output_acc: 0.3483 - val_weight_output_acc: 0.5630 - val_bag_output_acc: 0.5721 - val_footwear_output_acc: 0.5917 - val_pose_output_acc: 0.6915 - val_emotion_output_acc: 0.6462
#
# Epoch 00017: val_loss did not improve from 7.42904
# Epoch 18/96
# 180/180 [==============================] - 63s 351ms/step - loss: 4.0593 - gender_output_loss: 0.2528 - image_quality_output_loss: 0.5434 - age_output_loss: 0.7921 - weight_output_loss: 0.5931 - bag_output_loss: 0.4614 - footwear_output_loss: 0.4449 - pose_output_loss: 0.3257 - emotion_output_loss: 0.5121 - gender_output_acc: 0.8903 - image_quality_output_acc: 0.7597 - age_output_acc: 0.6756 - weight_output_acc: 0.7554 - bag_output_acc: 0.7999 - footwear_output_acc: 0.8122 - pose_output_acc: 0.8704 - emotion_output_acc: 0.8048 - val_loss: 10.1285 - val_gender_output_loss: 0.8426 - val_image_quality_output_loss: 1.2320 - val_age_output_loss: 1.9085 - val_weight_output_loss: 1.3108 - val_bag_output_loss: 1.2671 - val_footwear_output_loss: 1.2230 - val_pose_output_loss: 0.9677 - val_emotion_output_loss: 1.2430 - val_gender_output_acc: 0.6971 - val_image_quality_output_acc: 0.4834 - val_age_output_acc: 0.3322 - val_weight_output_acc: 0.5418 - val_bag_output_acc: 0.5484 - val_footwear_output_acc: 0.5811 - val_pose_output_acc: 0.6951 - val_emotion_output_acc: 0.5902
#
# Epoch 00018: val_loss did not improve from 7.42904
# Epoch 19/96
# 180/180 [==============================] - 63s 352ms/step - loss: 3.9998 - gender_output_loss: 0.2441 - image_quality_output_loss: 0.5382 - age_output_loss: 0.8069 - weight_output_loss: 0.5826 - bag_output_loss: 0.4456 - footwear_output_loss: 0.4390 - pose_output_loss: 0.3174 - emotion_output_loss: 0.4923 - gender_output_acc: 0.8947 - image_quality_output_acc: 0.7662 - age_output_acc: 0.6694 - weight_output_acc: 0.7584 - bag_output_acc: 0.8058 - footwear_output_acc: 0.8205 - pose_output_acc: 0.8735 - emotion_output_acc: 0.8141 - val_loss: 9.5927 - val_gender_output_loss: 0.8168 - val_image_quality_output_loss: 1.1798 - val_age_output_loss: 1.8406 - val_weight_output_loss: 1.1976 - val_bag_output_loss: 1.1859 - val_footwear_output_loss: 1.1263 - val_pose_output_loss: 0.8945 - val_emotion_output_loss: 1.2175 - val_gender_output_acc: 0.6966 - val_image_quality_output_acc: 0.4919 - val_age_output_acc: 0.3553 - val_weight_output_acc: 0.5801 - val_bag_output_acc: 0.5489 - val_footwear_output_acc: 0.5892 - val_pose_output_acc: 0.6638 - val_emotion_output_acc: 0.6492
#
# Epoch 00019: val_loss did not improve from 7.42904
# Epoch 20/96
# 180/180 [==============================] - 63s 351ms/step - loss: 3.9008 - gender_output_loss: 0.2527 - image_quality_output_loss: 0.5228 - age_output_loss: 0.7930 - weight_output_loss: 0.5512 - bag_output_loss: 0.4439 - footwear_output_loss: 0.4132 - pose_output_loss: 0.3289 - emotion_output_loss: 0.4611 - gender_output_acc: 0.8876 - image_quality_output_acc: 0.7751 - age_output_acc: 0.6749 - weight_output_acc: 0.7721 - bag_output_acc: 0.8042 - footwear_output_acc: 0.8297 - pose_output_acc: 0.8683 - emotion_output_acc: 0.8265 - val_loss: 10.6538 - val_gender_output_loss: 0.8759 - val_image_quality_output_loss: 1.4875 - val_age_output_loss: 1.9089 - val_weight_output_loss: 1.3217 - val_bag_output_loss: 1.3171 - val_footwear_output_loss: 1.3273 - val_pose_output_loss: 0.9541 - val_emotion_output_loss: 1.3273 - val_gender_output_acc: 0.6925 - val_image_quality_output_acc: 0.4708 - val_age_output_acc: 0.3352 - val_weight_output_acc: 0.5645 - val_bag_output_acc: 0.5418 - val_footwear_output_acc: 0.5842 - val_pose_output_acc: 0.6678 - val_emotion_output_acc: 0.6154
#
# Epoch 00020: val_loss did not improve from 7.42904

# %%
# view how LR has worked
plt.xlabel('Training Iterations')
plt.ylabel('Learning Rate')
plt.title("CLR - 'Exponential' Policy")
plt.plot(clr_used.history['iterations'], clr_used.history['lr'])

# %%
plot_model_history_loss(history)

# %%
plot_model_history_acc(history)

# %%
# Load best saved model
from keras.models import load_model
best_model = load_model("/content/attempt3_resnet5/person_model.010.h5")
#best_model = model

# %%
# Evaluate Model for test data
results = best_model.evaluate_generator(valid_gen, verbose=1)
results_dict = dict(zip(best_model.metrics_names, results))
# Out:
# 31/31 [==============================] - 4s 137ms/step

# %%
# get accuracies for each category
acc_results = {name:result for name, result in zip(best_model.metrics_names, results) if name.endswith("acc")}
print("Total Validation Loss: ", results_dict['loss'])
print("Validation Accuracies: ")
acc_results
# Out:
# Total Validation Loss:  7.429036955679616
# Validation Accuracies:
# {'age_output_acc': 0.3709677419354839,
#  'bag_output_acc': 0.5645161290322581,
#  'emotion_output_acc': 0.7106854838709677,
#  'footwear_output_acc': 0.6466733870967742,
#  'gender_output_acc': 0.7011088709677419,
#  'image_quality_output_acc': 0.5554435483870968,
#  'pose_output_acc': 0.7036290322580645,
#  'weight_output_acc': 0.6320564516129032}
