# %%
# mount gdrive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# unzip data
# !unzip -q "/content/gdrive/My Drive/TSAI/session5/hvc_data.zip"
# look for `hvc_annotations.csv` file and `resized` dir
# %ls
# Out:
# gdrive/  hvc_annotations.csv  resized/  sample_data/

# %%
# %tensorflow_version 1.x

import cv2
import json

import numpy as np
import pandas as pd
import os

from functools import partial
from pathlib import Path 
from tqdm import tqdm

from google.colab.patches import cv2_imshow

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder


from keras.applications import VGG16

from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.layers import GlobalAveragePooling2D, Dropout, MaxPooling2D
from keras.models import Model
from keras.optimizers import Adam
from keras.optimizers import SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2

from keras.preprocessing import image
from keras.utils.vis_utils import plot_model

from keras import backend as K

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# load annotations
df = pd.read_csv("hvc_annotations.csv")
del df["filename"] # remove unwanted column

print("Shape: ", df.shape)
df.head(3)
# Out:
# Shape:  (13573, 9)
#    gender imagequality    age  ...        emotion        bodypose     image_path
# 0    male      Average  35-45  ...        Neutral  Front-Frontish  resized/1.jpg
# 1  female      Average  35-45  ...  Angry/Serious  Front-Frontish  resized/2.jpg
# 2    male         Good  45-55  ...        Neutral  Front-Frontish  resized/3.jpg
#
# [3 rows x 9 columns]

# %%
# visualize few images
fig = plt.figure(figsize=(8,3))
for i in range(10):
  ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
  img = image.load_img(df.image_path[i])
  plt.imshow(img)
plt.show()

# %%
# utility function to view image properties and its labeling
def viewData(index):
  img = image.load_img(df.image_path[index])
  plt.imshow(img)
  print(df.iloc[index])

# %%
viewData(4864) # typical case of wrong labeling (Gender is wrongly labeled)
# Out:
# gender                              male
# imagequality                        Good
# age                                25-35
# weight                    normal-healthy
# carryingbag     Grocery/Home/Plastic Bag
# footwear                           Fancy
# emotion                          Neutral
# bodypose                  Front-Frontish
# image_path              resized/4865.jpg
# Name: 4864, dtype: object

# %%
# one hot encoding of labels

one_hot_df = pd.concat([
    df[["image_path"]],
    pd.get_dummies(df.gender, prefix="gender"),
    pd.get_dummies(df.imagequality, prefix="imagequality"),
    pd.get_dummies(df.age, prefix="age"),
    pd.get_dummies(df.weight, prefix="weight"),
    pd.get_dummies(df.carryingbag, prefix="carryingbag"),
    pd.get_dummies(df.footwear, prefix="footwear"),
    pd.get_dummies(df.emotion, prefix="emotion"),
    pd.get_dummies(df.bodypose, prefix="bodypose"),
], axis = 1)

# view one-hot encoding results
one_hot_df.head().T
# Out:
#                                                   0  ...              4
# image_path                            resized/1.jpg  ...  resized/5.jpg
# gender_female                                     0  ...              1
# gender_male                                       1  ...              0
# imagequality_Average                              1  ...              0
# imagequality_Bad                                  0  ...              0
# imagequality_Good                                 0  ...              1
# age_15-25                                         0  ...              0
# age_25-35                                         0  ...              0
# age_35-45                                         1  ...              1
# age_45-55                                         0  ...              0
# age_55+                                           0  ...              0
# weight_normal-healthy                             1  ...              0
# weight_over-weight                                0  ...              0
# weight_slightly-overweight                        0  ...              1
# weight_underweight                                0  ...              0
# carryingbag_Daily/Office/Work Bag                 0  ...              0
# carryingbag_Grocery/Home/Plastic Bag              1  ...              0
# carryingbag_None                                  0  ...              1
# footwear_CantSee                                  0  ...              1
# footwear_Fancy                                    0  ...              0
# footwear_Normal                                   1  ...              0
# emotion_Angry/Serious                             0  ...              0
# emotion_Happy                                     0  ...              0
# emotion_Neutral                                   1  ...              1
# emotion_Sad                                       0  ...              0
# bodypose_Back                                     0  ...              0
# bodypose_Front-Frontish                           1  ...              1
# bodypose_Side                                     0  ...              0
#
# [28 rows x 5 columns]

# %%
import keras
import numpy as np

# Label columns per attribute
_gender_cols_ = [col for col in one_hot_df.columns if col.startswith("gender")]
_imagequality_cols_ = [col for col in one_hot_df.columns if col.startswith("imagequality")]
_age_cols_ = [col for col in one_hot_df.columns if col.startswith("age")]
_weight_cols_ = [col for col in one_hot_df.columns if col.startswith("weight")]
_carryingbag_cols_ = [col for col in one_hot_df.columns if col.startswith("carryingbag")]
_footwear_cols_ = [col for col in one_hot_df.columns if col.startswith("footwear")]
_emotion_cols_ = [col for col in one_hot_df.columns if col.startswith("emotion")]
_bodypose_cols_ = [col for col in one_hot_df.columns if col.startswith("bodypose")]

class PersonDataGenerator(keras.utils.Sequence):
    """Ground truth data generator"""

    
    def __init__(self, df, batch_size=32, shuffle=True, data_augmentation=None):
        self.df = df
        self.batch_size=batch_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.data_augmentation = data_augmentation

    def __len__(self):
        return int(np.floor(self.df.shape[0] / self.batch_size))

    def __getitem__(self, index):
        """fetch batched images and targets"""
        batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
        items = self.df.iloc[batch_slice]
        image = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])

        # normalize the data
        image = image.astype('float32') / 255

        target = {
            "gender_output": items[_gender_cols_].values,
            "image_quality_output": items[_imagequality_cols_].values,
            "age_output": items[_age_cols_].values,
            "weight_output": items[_weight_cols_].values,
            "bag_output": items[_carryingbag_cols_].values,
            "pose_output": items[_bodypose_cols_].values,
            "footwear_output": items[_footwear_cols_].values,
            "emotion_output": items[_emotion_cols_].values,
        }

        if self.data_augmentation is not None:
            self.data_augmentation.fit(image)
            image = self.data_augmentation.flow(image, shuffle=False).next()

        return image, target

    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        if self.shuffle == True:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(one_hot_df, test_size=0.15)
train_df.shape, val_df.shape
# Out:
# ((11537, 28), (2036, 28))

# %%
def cutout_fxn(img):

    height = img.shape[0]
    width = img.shape[1]
    depth = img.shape[2]

    CUT_SIZE = 32 #height//4

    img_new = np.zeros((width+2*CUT_SIZE,height+2*CUT_SIZE, depth), np.float32)

    # normalize before adding the mask
    #mean = img.mean(keepdims=True)
    mean = np.mean(img, axis=(0, 1))
    img -= mean

    img_new[CUT_SIZE:width+CUT_SIZE,CUT_SIZE:height+CUT_SIZE,:] = img
    #print(mean)

    mask = np.ones((width+2*CUT_SIZE,height+2*CUT_SIZE,depth), np.float32)

    # after analysing the few images it is found that actual pictures are
    # at center of the image so cutout to be position accordingly
    offset = 50
 
    y1 = np.random.randint(height+CUT_SIZE)
    y2 = y1 + CUT_SIZE
    x1 = np.random.randint(offset, width+CUT_SIZE-offset)
    x2 = x1 + CUT_SIZE

    mask[y1: y2, x1: x2,:] = 0

    # apply mask
    img_new = img_new * mask

    # denormalize
    img_new += mean

    final_img = img_new[CUT_SIZE:width+CUT_SIZE,CUT_SIZE:height+CUT_SIZE,:]

    return final_img

def lr_schedule(epoch, lr):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after each epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = round(0.0001 * 1/(1 + 0.001 * epoch), 10)
    return lr

# %%
# applying data augmentation
datagen = ImageDataGenerator(
        # randomly flip images
        horizontal_flip=True,
        # set function that will be applied on each input
        preprocessing_function=cutout_fxn
    )

# %%
# create train and validation data generators
train_gen = PersonDataGenerator(train_df, batch_size=32, data_augmentation = datagen)
valid_gen = PersonDataGenerator(val_df, batch_size=64, shuffle=False)

# %%
# get number of output units from data
images, targets = next(iter(train_gen))
num_units = { k.split("_output")[0]:v.shape[1] for k, v in targets.items()}
num_units
# Out:
# {'age': 5,
#  'bag': 3,
#  'emotion': 4,
#  'footwear': 3,
#  'gender': 2,
#  'image_quality': 3,
#  'pose': 3,
#  'weight': 4}

# %%
# viewing augmented image, cutout portion 
cv2_imshow(images[10]*255)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7EFE7D72F470>

# %%
# viewing augmented image, cutout portion 
cv2_imshow(images[20]*255)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7EFE7D72F3C8>

# %%
backbone = VGG16(
    weights=None, # no pre-trained weights
    include_top=False, 
    input_tensor=Input(shape=(224, 224, 3))
)

neck = backbone.output
neck = Flatten(name="flatten")(neck)
neck = Dense(512, activation="relu")(neck)

def build_tower(in_layer):
    neck = Dropout(0.50)(in_layer)
    neck = BatchNormalization()(neck)
    neck = Dense(128, activation="relu")(neck)
    neck = Dropout(0.50)(neck)
    neck = Dense(128, activation="relu")(neck)
    return neck

def build_tower1(in_layer):
    neck = Dropout(0.50)(in_layer)
    neck = BatchNormalization()(neck)
    neck = Dense(256, activation="relu")(neck)
    neck = Dropout(0.50)(neck)
    neck = Dense(256, activation="relu")(neck)
    return neck


def build_head(name, in_layer):
    return Dense(
        num_units[name], activation="softmax", name=f"{name}_output"
    )(in_layer)

def build_head1(name, in_layer):
    return Dense(
        num_units[name], activation="sigmoid", name=f"{name}_output"
    )(in_layer)

# heads
gender = build_head1("gender", build_tower(neck))
image_quality = build_head("image_quality", build_tower1(neck))
age = build_head("age", build_tower1(neck))
weight = build_head("weight", build_tower(neck))
bag = build_head("bag", build_tower(neck))
footwear = build_head("footwear", build_tower(neck))
emotion = build_head("emotion", build_tower(neck))
pose = build_head("pose", build_tower(neck))


model = Model(
    inputs=backbone.input, 
    outputs=[gender, image_quality, age, weight, bag, footwear, pose, emotion]
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
# # freeze backbone
# for layer in backbone.layers:
# 	layer.trainable = False

# %%
#plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
plot_model(model, to_file='model_plot.png', show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 224, 224, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 224, 224, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 112, 112, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 112, 112, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 112, 112, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 56, 56, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 56, 56, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 28, 28, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 28, 28, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 14, 14, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 14, 14, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 7, 7, 512)    0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 25088)        0           block5_pool[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          12845568    flatten[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 512)          2048        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 512)          2048        dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 512)          2048        dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 512)          2048        dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 512)          2048        dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 512)          2048        dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 512)          2048        dropout_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 512)          2048        dropout_13[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          65664       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 256)          131328      batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 256)          131328      batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 128)          65664       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 128)          65664       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 128)          65664       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 128)          65664       batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 128)          65664       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 256)          0           dense_4[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 256)          0           dense_6[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 128)          0           dense_8[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 128)          0           dense_10[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 128)          0           dense_12[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 128)          0           dense_16[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 128)          0           dense_14[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          16512       dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 256)          65792       dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 256)          65792       dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 128)          16512       dropout_8[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 128)          16512       dropout_10[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 128)          16512       dropout_12[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 128)          16512       dropout_16[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 128)          16512       dropout_14[0][0]
# __________________________________________________________________________________________________
# gender_output (Dense)           (None, 2)            258         dense_3[0][0]
# __________________________________________________________________________________________________
# image_quality_output (Dense)    (None, 3)            771         dense_5[0][0]
# __________________________________________________________________________________________________
# age_output (Dense)              (None, 5)            1285        dense_7[0][0]
# __________________________________________________________________________________________________
# weight_output (Dense)           (None, 4)            516         dense_9[0][0]
# __________________________________________________________________________________________________
# bag_output (Dense)              (None, 3)            387         dense_11[0][0]
# __________________________________________________________________________________________________
# footwear_output (Dense)         (None, 3)            387         dense_13[0][0]
# __________________________________________________________________________________________________
# pose_output (Dense)             (None, 3)            387         dense_17[0][0]
# __________________________________________________________________________________________________
# emotion_output (Dense)          (None, 4)            516         dense_15[0][0]
# ==================================================================================================
# Total params: 28,468,443
# Trainable params: 28,460,251
# Non-trainable params: 8,192
# __________________________________________________________________________________________________

# %%
losses = {
 	"gender_output": "binary_crossentropy",
 	"image_quality_output": "categorical_crossentropy",
 	"age_output": "categorical_crossentropy",
 	"weight_output": "categorical_crossentropy",
  "bag_output": "categorical_crossentropy",
  "footwear_output": "categorical_crossentropy",
  "pose_output": "categorical_crossentropy",
  "emotion_output": "categorical_crossentropy",
 }

loss_weights = {
 	"gender_output": 1.0,
 	"image_quality_output": 1.0,
 	"age_output": 1.0,
 	"weight_output": 1.0,
  "bag_output": 1.0,
  "footwear_output": 1.0,
  "pose_output": 1.0,
  "emotion_output": 1.0,
 }


opt = SGD(lr=0.0001, momentum=0.9)
model.compile(
    optimizer=opt,
    loss=losses, 
    loss_weights=loss_weights, 
    metrics=["accuracy"]
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
from keras.callbacks import EarlyStopping

# Prepare model saving directory.
save_dir = os.path.join(os.getcwd(), 'attempt2_savedlr1')
#model_name = 'person_model_best.h5'
model_name = 'person_model.{epoch:03d}.h5'

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# using tensorboard callback.
# utility fxn for Initializing Early stopping and Model chekpoint callbacks**
def EarlyStopingModelCheckPoint():
    
    #Adding Early stopping callback to the fit function is going to stop the training,
    #if the val_loss is not going to change even '0.001' for more than 10 continous epochs
    # this help to save training time and not to keep  training if loss doesn not improve

    early_stopping = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=10)

    #Adding Model Checkpoint callback to the fit function is going to save the weights whenever val_loss achieves 
    # a new low value. Hence saving the best weights occurred during training
    model_checkpoint =  ModelCheckpoint(filepath=filepath,
                                           monitor='val_loss',
                                           verbose=1,
                                           save_best_only=True,
                                           mode='auto',
                                           period=1)
    return early_stopping, model_checkpoint

# %%
from keras.callbacks import *
from keras.optimizers import *

class CyclicLR(Callback):
    """This callback implements a cyclical learning rate policy (CLR).
    The method cycles the learning rate between two boundaries with
    some constant frequency, as detailed in this paper (https://arxiv.org/abs/1506.01186).
    The amplitude of the cycle can be scaled on a per-iteration or 
    per-cycle basis.
    This class has three built-in policies, as put forth in the paper.
    "triangular":
        A basic triangular cycle w/ no amplitude scaling.
    "triangular2":
        A basic triangular cycle that scales initial amplitude by half each cycle.
    "exp_range":
        A cycle that scales initial amplitude by gamma**(cycle iterations) at each 
        cycle iteration.
    For more detail, please see paper.
    
    # Example
        ```python
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., mode='triangular')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```
    
    Class also supports custom scaling functions:
        ```python
            clr_fn = lambda x: 0.5*(1+np.sin(x*np.pi/2.))
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., scale_fn=clr_fn,
                                scale_mode='cycle')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```    
    # Arguments
        base_lr: initial learning rate which is the
            lower boundary in the cycle.
        max_lr: upper boundary in the cycle. Functionally,
            it defines the cycle amplitude (max_lr - base_lr).
            The lr at any cycle is the sum of base_lr
            and some scaling of the amplitude; therefore 
            max_lr may not actually be reached depending on
            scaling function.
        step_size: number of training iterations per
            half cycle. Authors suggest setting step_size
            2-8 x training iterations in epoch.
        mode: one of {triangular, triangular2, exp_range}.
            Default 'triangular'.
            Values correspond to policies detailed above.
            If scale_fn is not None, this argument is ignored.
        gamma: constant in 'exp_range' scaling function:
            gamma**(cycle iterations)
        scale_fn: Custom scaling policy defined by a single
            argument lambda function, where 
            0 <= scale_fn(x) <= 1 for all x >= 0.
            mode paramater is ignored 
        scale_mode: {'cycle', 'iterations'}.
            Defines whether scale_fn is evaluated on 
            cycle number or cycle iterations (training
            iterations since start of cycle). Default is 'cycle'.
    """

    def __init__(self, base_lr=0.001, max_lr=0.006, step_size=2000., mode='triangular',
                 gamma=1., scale_fn=None, scale_mode='cycle'):
        super(CyclicLR, self).__init__()

        self.base_lr = base_lr
        self.max_lr = max_lr
        self.step_size = step_size
        self.mode = mode
        self.gamma = gamma
        if scale_fn == None:
            if self.mode == 'triangular':
                self.scale_fn = lambda x: 1.
                self.scale_mode = 'cycle'
            elif self.mode == 'triangular2':
                self.scale_fn = lambda x: 1/(2.**(x-1))
                self.scale_mode = 'cycle'
            elif self.mode == 'exp_range':
                self.scale_fn = lambda x: gamma**(x)
                self.scale_mode = 'iterations'
        else:
            self.scale_fn = scale_fn
            self.scale_mode = scale_mode
        self.clr_iterations = 0.
        self.trn_iterations = 0.
        self.history = {}

        self._reset()

    def _reset(self, new_base_lr=None, new_max_lr=None,
               new_step_size=None):
        """Resets cycle iterations.
        Optional boundary/step size adjustment.
        """
        if new_base_lr != None:
            self.base_lr = new_base_lr
        if new_max_lr != None:
            self.max_lr = new_max_lr
        if new_step_size != None:
            self.step_size = new_step_size
        self.clr_iterations = 0.
        
    def clr(self):
        cycle = np.floor(1+self.clr_iterations/(2*self.step_size))
        x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1)
        if self.scale_mode == 'cycle':
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(cycle)
        else:
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(self.clr_iterations)
        
    def on_train_begin(self, logs={}):
        logs = logs or {}

        if self.clr_iterations == 0:
            K.set_value(self.model.optimizer.lr, self.base_lr)
        else:
            K.set_value(self.model.optimizer.lr, self.clr())        
            
    def on_batch_end(self, epoch, logs=None):
        
        logs = logs or {}
        self.trn_iterations += 1
        self.clr_iterations += 1

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.trn_iterations)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        
        K.set_value(self.model.optimizer.lr, self.clr())

# %%
# Prepare callback for cyclic LR
batch_size = 32
step_size= 8 * (train_df.shape[0] // batch_size)

#Triangular policy
clr_triangular = CyclicLR(base_lr=0.00001, max_lr=0.0001, step_size=step_size, mode='triangular')

clr_triangular2 = CyclicLR(mode='triangular2')

# Exponential policy
#clr_exp = CyclicLR(mode='exp_range', gamma=0.99994, base_lr=0.00001, max_lr=0.0001, step_size=step_size)
clr_exp = CyclicLR(mode='exp_range', gamma=0.99994, base_lr=0.000001, max_lr=0.0001, step_size=step_size)

#CLR - Custom Sinusoidal Cycle-Policy
clr_scale_fxn = lambda x: 0.5*(1+np.sin(x*np.pi/2.))
clr_sine = CyclicLR(scale_fn=clr_scale_fxn, scale_mode='cycle', base_lr=0.00001, max_lr=0.0001, step_size=step_size )

# %%
step_size
# Out:
# 2880

# %%
# Prepare callbacks for model saving and for learning rate adjustment.

early_stopping, model_checkpoint = EarlyStopingModelCheckPoint()

lr_scheduler = LearningRateScheduler(lr_schedule, verbose=1)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=2, #patience=5
                               min_lr=0.5e-6)
callbacks = [early_stopping, model_checkpoint, clr_exp]

# %%
history = model.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    use_multiprocessing=True,
    workers=6, 
    epochs=60,
    verbose=1,
    callbacks=callbacks
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# Epoch 1/60
# 359/360 [============================>.] - ETA: 0s - loss: 9.4500 - gender_output_loss: 0.6928 - image_quality_output_loss: 1.0944 - age_output_loss: 1.6068 - weight_output_loss: 1.3743 - bag_output_loss: 1.1069 - footwear_output_loss: 1.0949 - pose_output_loss: 1.0874 - emotion_output_loss: 1.3925 - gender_output_acc: 0.5087 - image_quality_output_acc: 0.4070 - age_output_acc: 0.2330 - weight_output_acc: 0.3649 - bag_output_acc: 0.2162 - footwear_output_acc: 0.3752 - pose_output_acc: 0.5034 - emotion_output_acc: 0.2077
# 360/360 [==============================] - 118s 329ms/step - loss: 9.4500 - gender_output_loss: 0.6928 - image_quality_output_loss: 1.0944 - age_output_loss: 1.6068 - weight_output_loss: 1.3743 - bag_output_loss: 1.1069 - footwear_output_loss: 1.0949 - pose_output_loss: 1.0874 - emotion_output_loss: 1.3925 - gender_output_acc: 0.5088 - image_quality_output_acc: 0.4070 - age_output_acc: 0.2333 - weight_output_acc: 0.3650 - bag_output_acc: 0.2162 - footwear_output_acc: 0.3756 - pose_output_acc: 0.5032 - emotion_output_acc: 0.2076 - val_loss: 9.4317 - val_gender_output_loss: 0.6930 - val_image_quality_output_loss: 1.0972 - val_age_output_loss: 1.6064 - val_weight_output_loss: 1.3713 - val_bag_output_loss: 1.1063 - val_footwear_output_loss: 1.0928 - val_pose_output_loss: 1.0912 - val_emotion_output_loss: 1.3734 - val_gender_output_acc: 0.4987 - val_image_quality_output_acc: 0.4163 - val_age_output_acc: 0.2858 - val_weight_output_acc: 0.6462 - val_bag_output_acc: 0.0993 - val_footwear_output_acc: 0.3770 - val_pose_output_acc: 0.5948 - val_emotion_output_acc: 0.6986
#
# Epoch 00001: val_loss improved from inf to 9.43173, saving model to /content/attempt2_savedlr1/person_model.001.h5
# Epoch 2/60
# 360/360 [==============================] - 104s 290ms/step - loss: 9.3541 - gender_output_loss: 0.6927 - image_quality_output_loss: 1.0839 - age_output_loss: 1.5981 - weight_output_loss: 1.3475 - bag_output_loss: 1.1075 - footwear_output_loss: 1.0892 - pose_output_loss: 1.0666 - emotion_output_loss: 1.3685 - gender_output_acc: 0.5138 - image_quality_output_acc: 0.4588 - age_output_acc: 0.2736 - weight_output_acc: 0.4857 - bag_output_acc: 0.2784 - footwear_output_acc: 0.3883 - pose_output_acc: 0.5586 - emotion_output_acc: 0.3664 - val_loss: 9.2780 - val_gender_output_loss: 0.6937 - val_image_quality_output_loss: 1.0733 - val_age_output_loss: 1.5849 - val_weight_output_loss: 1.3481 - val_bag_output_loss: 1.0863 - val_footwear_output_loss: 1.0919 - val_pose_output_loss: 1.0734 - val_emotion_output_loss: 1.3266 - val_gender_output_acc: 0.4602 - val_image_quality_output_acc: 0.5504 - val_age_output_acc: 0.3987 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5519 - val_footwear_output_acc: 0.3765 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00002: val_loss improved from 9.43173 to 9.27803, saving model to /content/attempt2_savedlr1/person_model.002.h5
# Epoch 3/60
# 360/360 [==============================] - 104s 290ms/step - loss: 9.1701 - gender_output_loss: 0.6931 - image_quality_output_loss: 1.0634 - age_output_loss: 1.5806 - weight_output_loss: 1.2970 - bag_output_loss: 1.1007 - footwear_output_loss: 1.0829 - pose_output_loss: 1.0346 - emotion_output_loss: 1.3177 - gender_output_acc: 0.5088 - image_quality_output_acc: 0.4951 - age_output_acc: 0.3163 - weight_output_acc: 0.5656 - bag_output_acc: 0.3446 - footwear_output_acc: 0.3898 - pose_output_acc: 0.5829 - emotion_output_acc: 0.5026 - val_loss: 9.0889 - val_gender_output_loss: 0.6888 - val_image_quality_output_loss: 1.0653 - val_age_output_loss: 1.5807 - val_weight_output_loss: 1.2868 - val_bag_output_loss: 1.0736 - val_footwear_output_loss: 1.0898 - val_pose_output_loss: 1.0473 - val_emotion_output_loss: 1.2566 - val_gender_output_acc: 0.5696 - val_image_quality_output_acc: 0.5504 - val_age_output_acc: 0.3987 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5575 - val_footwear_output_acc: 0.4728 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00003: val_loss improved from 9.27803 to 9.08892, saving model to /content/attempt2_savedlr1/person_model.003.h5
# Epoch 4/60
# 359/360 [============================>.] - ETA: 0s - loss: 8.8745 - gender_output_loss: 0.6947 - image_quality_output_loss: 1.0342 - age_output_loss: 1.5506 - weight_output_loss: 1.2192 - bag_output_loss: 1.0801 - footwear_output_loss: 1.0779 - pose_output_loss: 0.9951 - emotion_output_loss: 1.2226 - gender_output_acc: 0.5119 - image_quality_output_acc: 0.5245 - age_output_acc: 0.3417 - weight_output_acc: 0.6041 - bag_output_acc: 0.4083 - footwear_output_acc: 0.3939 - pose_output_acc: 0.6025 - emotion_output_acc: 0.6119
# Epoch 00003: val_loss improved from 9.27803 to 9.08892, saving model to /content/attempt2_savedlr1/person_model.003.h5
# 360/360 [==============================] - 105s 291ms/step - loss: 8.8741 - gender_output_loss: 0.6948 - image_quality_output_loss: 1.0342 - age_output_loss: 1.5505 - weight_output_loss: 1.2191 - bag_output_loss: 1.0799 - footwear_output_loss: 1.0778 - pose_output_loss: 0.9952 - emotion_output_loss: 1.2226 - gender_output_acc: 0.5120 - image_quality_output_acc: 0.5243 - age_output_acc: 0.3420 - weight_output_acc: 0.6040 - bag_output_acc: 0.4089 - footwear_output_acc: 0.3937 - pose_output_acc: 0.6022 - emotion_output_acc: 0.6122 - val_loss: 8.8403 - val_gender_output_loss: 0.6968 - val_image_quality_output_loss: 1.0476 - val_age_output_loss: 1.5588 - val_weight_output_loss: 1.2131 - val_bag_output_loss: 1.0502 - val_footwear_output_loss: 1.0663 - val_pose_output_loss: 1.0123 - val_emotion_output_loss: 1.1952 - val_gender_output_acc: 0.4299 - val_image_quality_output_acc: 0.5504 - val_age_output_acc: 0.3987 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5575 - val_footwear_output_acc: 0.3967 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00004: val_loss improved from 9.08892 to 8.84029, saving model to /content/attempt2_savedlr1/person_model.004.h5
# Epoch 5/60
# 360/360 [==============================] - 104s 290ms/step - loss: 8.5150 - gender_output_loss: 0.6979 - image_quality_output_loss: 1.0131 - age_output_loss: 1.5104 - weight_output_loss: 1.1337 - bag_output_loss: 1.0372 - footwear_output_loss: 1.0700 - pose_output_loss: 0.9652 - emotion_output_loss: 1.0875 - gender_output_acc: 0.5123 - image_quality_output_acc: 0.5398 - age_output_acc: 0.3701 - weight_output_acc: 0.6260 - bag_output_acc: 0.4789 - footwear_output_acc: 0.4076 - pose_output_acc: 0.6080 - emotion_output_acc: 0.6932 - val_loss: 8.6994 - val_gender_output_loss: 0.6920 - val_image_quality_output_loss: 1.0324 - val_age_output_loss: 1.5452 - val_weight_output_loss: 1.2100 - val_bag_output_loss: 1.0146 - val_footwear_output_loss: 1.0649 - val_pose_output_loss: 1.0125 - val_emotion_output_loss: 1.1277 - val_gender_output_acc: 0.5567 - val_image_quality_output_acc: 0.5504 - val_age_output_acc: 0.3987 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5575 - val_footwear_output_acc: 0.5318 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00005: val_loss improved from 8.84029 to 8.69936, saving model to /content/attempt2_savedlr1/person_model.005.h5
# Epoch 6/60
# 360/360 [==============================] - 104s 290ms/step - loss: 8.2483 - gender_output_loss: 0.6977 - image_quality_output_loss: 1.0033 - age_output_loss: 1.4814 - weight_output_loss: 1.0747 - bag_output_loss: 0.9895 - footwear_output_loss: 1.0584 - pose_output_loss: 0.9538 - emotion_output_loss: 0.9897 - gender_output_acc: 0.5210 - image_quality_output_acc: 0.5439 - age_output_acc: 0.3779 - weight_output_acc: 0.6314 - bag_output_acc: 0.5252 - footwear_output_acc: 0.4240 - pose_output_acc: 0.6141 - emotion_output_acc: 0.7111 - val_loss: 8.4898 - val_gender_output_loss: 0.6874 - val_image_quality_output_loss: 1.0325 - val_age_output_loss: 1.5165 - val_weight_output_loss: 1.1410 - val_bag_output_loss: 0.9948 - val_footwear_output_loss: 1.0439 - val_pose_output_loss: 0.9888 - val_emotion_output_loss: 1.0850 - val_gender_output_acc: 0.5696 - val_image_quality_output_acc: 0.5504 - val_age_output_acc: 0.3987 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5575 - val_footwear_output_acc: 0.4803 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00006: val_loss improved from 8.69936 to 8.48984, saving model to /content/attempt2_savedlr1/person_model.006.h5
# Epoch 7/60
# 359/360 [============================>.] - ETA: 0s - loss: 8.1307 - gender_output_loss: 0.6945 - image_quality_output_loss: 1.0039 - age_output_loss: 1.4709 - weight_output_loss: 1.0511 - bag_output_loss: 0.9634 - footwear_output_loss: 1.0464 - pose_output_loss: 0.9464 - emotion_output_loss: 0.9542 - gender_output_acc: 0.5245 - image_quality_output_acc: 0.5463 - age_output_acc: 0.3857 - weight_output_acc: 0.6324 - bag_output_acc: 0.5424 - footwear_output_acc: 0.4493 - pose_output_acc: 0.6170 - emotion_output_acc: 0.7138
# 360/360 [==============================] - 104s 290ms/step - loss: 8.1306 - gender_output_loss: 0.6945 - image_quality_output_loss: 1.0037 - age_output_loss: 1.4709 - weight_output_loss: 1.0511 - bag_output_loss: 0.9628 - footwear_output_loss: 1.0465 - pose_output_loss: 0.9461 - emotion_output_loss: 0.9550 - gender_output_acc: 0.5244 - image_quality_output_acc: 0.5464 - age_output_acc: 0.3859 - weight_output_acc: 0.6325 - bag_output_acc: 0.5429 - footwear_output_acc: 0.4493 - pose_output_acc: 0.6172 - emotion_output_acc: 0.7135 - val_loss: 8.3473 - val_gender_output_loss: 0.6870 - val_image_quality_output_loss: 1.0252 - val_age_output_loss: 1.5062 - val_weight_output_loss: 1.1012 - val_bag_output_loss: 0.9710 - val_footwear_output_loss: 1.0387 - val_pose_output_loss: 0.9825 - val_emotion_output_loss: 1.0355 - val_gender_output_acc: 0.5696 - val_image_quality_output_acc: 0.5504 - val_age_output_acc: 0.3987 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5575 - val_footwear_output_acc: 0.5378 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00007: val_loss improved from 8.48984 to 8.34733, saving model to /content/attempt2_savedlr1/person_model.007.h5
# Epoch 8/60
# 359/360 [============================>.] - ETA: 0s - loss: 8.0444 - gender_output_loss: 0.6927 - image_quality_output_loss: 0.9966 - age_output_loss: 1.4601 - weight_output_loss: 1.0325 - bag_output_loss: 0.9469 - footwear_output_loss: 1.0316 - pose_output_loss: 0.9450 - emotion_output_loss: 0.9390 - gender_output_acc: 0.5371 - image_quality_output_acc: 0.5501 - age_output_acc: 0.3870 - weight_output_acc: 0.6335 - bag_output_acc: 0.5500 - footwear_output_acc: 0.4691 - pose_output_acc: 0.6178 - emotion_output_acc: 0.7130
# Epoch 00007: val_loss improved from 8.48984 to 8.34733, saving model to /content/attempt2_savedlr1/person_model.007.h5
# 360/360 [==============================] - 104s 289ms/step - loss: 8.0440 - gender_output_loss: 0.6928 - image_quality_output_loss: 0.9965 - age_output_loss: 1.4602 - weight_output_loss: 1.0320 - bag_output_loss: 0.9472 - footwear_output_loss: 1.0318 - pose_output_loss: 0.9452 - emotion_output_loss: 0.9384 - gender_output_acc: 0.5370 - image_quality_output_acc: 0.5499 - age_output_acc: 0.3873 - weight_output_acc: 0.6339 - bag_output_acc: 0.5497 - footwear_output_acc: 0.4691 - pose_output_acc: 0.6175 - emotion_output_acc: 0.7134 - val_loss: 8.1423 - val_gender_output_loss: 0.6882 - val_image_quality_output_loss: 1.0108 - val_age_output_loss: 1.4765 - val_weight_output_loss: 1.0636 - val_bag_output_loss: 0.9638 - val_footwear_output_loss: 1.0154 - val_pose_output_loss: 0.9571 - val_emotion_output_loss: 0.9670 - val_gender_output_acc: 0.5512 - val_image_quality_output_acc: 0.5504 - val_age_output_acc: 0.3987 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5575 - val_footwear_output_acc: 0.5302 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00008: val_loss improved from 8.34733 to 8.14233, saving model to /content/attempt2_savedlr1/person_model.008.h5
# Epoch 9/60
# 360/360 [==============================] - 103s 287ms/step - loss: 7.9817 - gender_output_loss: 0.6919 - image_quality_output_loss: 0.9954 - age_output_loss: 1.4584 - weight_output_loss: 1.0175 - bag_output_loss: 0.9350 - footwear_output_loss: 1.0073 - pose_output_loss: 0.9418 - emotion_output_loss: 0.9344 - gender_output_acc: 0.5352 - image_quality_output_acc: 0.5483 - age_output_acc: 0.3877 - weight_output_acc: 0.6332 - bag_output_acc: 0.5561 - footwear_output_acc: 0.5099 - pose_output_acc: 0.6175 - emotion_output_acc: 0.7132 - val_loss: 8.0426 - val_gender_output_loss: 0.6911 - val_image_quality_output_loss: 0.9955 - val_age_output_loss: 1.4692 - val_weight_output_loss: 1.0085 - val_bag_output_loss: 0.9612 - val_footwear_output_loss: 0.9971 - val_pose_output_loss: 0.9521 - val_emotion_output_loss: 0.9679 - val_gender_output_acc: 0.5411 - val_image_quality_output_acc: 0.5504 - val_age_output_acc: 0.3987 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5575 - val_footwear_output_acc: 0.
- pose_output_acc: 0.6173 - emotion_output_acc: 0.7134 - val_loss: 7.9770 - val_gender_output_loss: 0.6816 - val_image_quality_output_loss: 0.9942 - val_age_output_loss: 1.4588 - val_weight_output_loss: 1.0200 - val_bag_output_loss: 0.9373 - val_footwear_output_loss: 0.9640 - val_pose_output_loss: 0.9527 - val_emotion_output_loss: 0.9684 - val_gender_output_acc: 0.5721 - val_image_quality_output_acc: 0.5504 - val_age_output_acc: 0.3987 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5575 - val_footwear_output_acc: 0.5549 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00012: val_loss improved from 7.98239 to 7.97700, saving model to /content/attempt2_savedlr1/person_model.012.h5
# Epoch 13/60
# 360/360 [==============================] - 103s 287ms/step - loss: 7.8782 - gender_output_loss: 0.6833 - image_quality_output_loss: 0.9903 - age_output_loss: 1.4448 - weight_output_loss: 1.0051 - bag_output_loss: 0.9265 - footwear_output_loss: 0.9690 - pose_output_loss: 0.9353 - emotion_output_loss: 0.9240 - gender_output_acc: 0.5558 - image_quality_output_acc: 0.5486 - age_output_acc: 0.3909 - weight_output_acc: 0.6337 - bag_output_acc: 0.5612 - footwear_output_acc: 0.5529 - pose_output_acc: 0.6178 - emotion_output_acc: 0.7134 - val_loss: 7.9463 - val_gender_output_loss: 0.6769 - val_image_quality_output_loss: 0.9954 - val_age_output_loss: 1.4563 - val_weight_output_loss: 1.0142 - val_bag_output_loss: 0.9362 - val_footwear_output_loss: 0.9571 - val_pose_output_loss: 0.9513 - val_emotion_output_loss: 0.9588 - val_gender_output_acc: 0.5748 - val_image_quality_output_acc: 0.5499 - val_age_output_acc: 0.4012 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5575 - val_footwear_output_acc: 0.5565 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00013: val_loss improved from 7.97700 to 7.94628, saving model to /content/attempt2_savedlr1/person_model.013.h5
# Epoch 14/60
# 360/360 [==============================] - 104s 289ms/step - loss: 7.8516 - gender_output_loss: 0.6819 - image_quality_output_loss: 0.9883 - age_output_loss: 1.4375 - weight_output_loss: 1.0029 - bag_output_loss: 0.9231 - footwear_output_loss: 0.9618 - pose_output_loss: 0.9362 - emotion_output_loss: 0.9199 - gender_output_acc: 0.5586 - image_quality_output_acc: 0.5490 - age_output_acc: 0.3938 - weight_output_acc: 0.6342 - bag_output_acc: 0.5600 - footwear_output_acc: 0.5543 - pose_output_acc: 0.6173 - emotion_output_acc: 0.7132 - val_loss: 7.9397 - val_gender_output_loss: 0.6755 - val_image_quality_output_loss: 0.9945 - val_age_output_loss: 1.4569 - val_weight_output_loss: 1.0183 - val_bag_output_loss: 0.9361 - val_footwear_output_loss: 0.9503 - val_pose_output_loss: 0.9505 - val_emotion_output_loss: 0.9576 - val_gender_output_acc: 0.5718 - val_image_quality_output_acc: 0.5504 - val_age_output_acc: 0.3987 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5575 - val_footwear_output_acc: 0.5640 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00014: val_loss improved from 7.94628 to 7.93968, saving model to /content/attempt2_savedlr1/person_model.014.h5
# Epoch 15/60
# 360/360 [==============================] - 104s 288ms/step - loss: 7.8474 - gender_output_loss: 0.6804 - image_quality_output_loss: 0.9869 - age_output_loss: 1.4386 - weight_output_loss: 1.0009 - bag_output_loss: 0.9204 - footwear_output_loss: 0.9644 - pose_output_loss: 0.9322 - emotion_output_loss: 0.9236 - gender_output_acc: 0.5606 - image_quality_output_acc: 0.5529 - age_output_acc: 0.3907 - weight_output_acc: 0.6342 - bag_output_acc: 0.5597 - footwear_output_acc: 0.5549 - pose_output_acc: 0.6179 - emotion_output_acc: 0.7135 - val_loss: 7.9373 - val_gender_output_loss: 0.6776 - val_image_quality_output_loss: 0.9996 - val_age_output_loss: 1.4522 - val_weight_output_loss: 1.0171 - val_bag_output_loss: 0.9362 - val_footwear_output_loss: 0.9545 - val_pose_output_loss: 0.9473 - val_emotion_output_loss: 0.9528 - val_gender_output_acc: 0.5819 - val_image_quality_output_acc: 0.5519 - val_age_output_acc: 0.4017 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5565 - val_footwear_output_acc: 0.5600 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00015: val_loss improved from 7.93968 to 7.93728, saving model to /content/attempt2_savedlr1/person_model.015.h5
# Epoch 16/60
# 360/360 [==============================] - 104s 289ms/step - loss: 7.8407 - gender_output_loss: 0.6794 - image_quality_output_loss: 0.9862 - age_output_loss: 1.4378 - weight_output_loss: 0.9980 - bag_output_loss: 0.9226 - footwear_output_loss: 0.9598 - pose_output_loss: 0.9353 - emotion_output_loss: 0.9217 - gender_output_acc: 0.5644 - image_quality_output_acc: 0.5539 - age_output_acc: 0.3933 - weight_output_acc: 0.6345 - bag_output_acc: 0.5605 - footwear_output_acc: 0.5492 - pose_output_acc: 0.6179 - emotion_output_acc: 0.7135 - val_loss: 7.9285 - val_gender_output_loss: 0.6765 - val_image_quality_output_loss: 0.9964 - val_age_output_loss: 1.4551 - val_weight_output_loss: 1.0132 - val_bag_output_loss: 0.9358 - val_footwear_output_loss: 0.9505 - val_pose_output_loss: 0.9482 - val_emotion_output_loss: 0.9529 - val_gender_output_acc: 0.5837 - val_image_quality_output_acc: 0.5524 - val_age_output_acc: 0.4007 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5570 - val_footwear_output_acc: 0.5625 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00016: val_loss improved from 7.93728 to 7.92850, saving model to /content/attempt2_savedlr1/person_model.016.h5
# Epoch 17/60
# 360/360 [==============================] - 104s 288ms/step - loss: 7.8451 - gender_output_loss: 0.6809 - image_quality_output_loss: 0.9878 - age_output_loss: 1.4378 - weight_output_loss: 1.0031 - bag_output_loss: 0.9205 - footwear_output_loss: 0.9579 - pose_output_loss: 0.9347 - emotion_output_loss: 0.9225 - gender_output_acc: 0.5590 - image_quality_output_acc: 0.5516 - age_output_acc: 0.3911 - weight_output_acc: 0.6343 - bag_output_acc: 0.5585 - footwear_output_acc: 0.5608 - pose_output_acc: 0.6179 - emotion_output_acc: 0.7133 - val_loss: 7.9169 - val_gender_output_loss: 0.6758 - val_image_quality_output_loss: 0.9948 - val_age_output_loss: 1.4535 - val_weight_output_loss: 1.0098 - val_bag_output_loss: 0.9356 - val_footwear_output_loss: 0.9488 - val_pose_output_loss: 0.9468 - val_emotion_output_loss: 0.9518 - val_gender_output_acc: 0.5859 - val_image_quality_output_acc: 0.5489 - val_age_output_acc: 0.4022 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5570 - val_footwear_output_acc: 0.5645 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00017: val_loss improved from 7.92850 to 7.91694, saving model to /content/attempt2_savedlr1/person_model.017.h5
# Epoch 18/60
# 359/360 [============================>.] - ETA: 0s - loss: 7.8351 - gender_output_loss: 0.6818 - image_quality_output_loss: 0.9859 - age_output_loss: 1.4363 - weight_output_loss: 1.0019 - bag_output_loss: 0.9199 - footwear_output_loss: 0.9552 - pose_output_loss: 0.9351 - emotion_output_loss: 0.9191 - gender_output_acc: 0.5519 - image_quality_output_acc: 0.5501 - age_output_acc: 0.3944 - weight_output_acc: 0.6341 - bag_output_acc: 0.5622 - footwear_output_acc: 0.5584 - pose_output_acc: 0.6175 - emotion_output_acc: 0.7134
# Epoch 00017: val_loss improved from 7.92850 to 7.91694, saving model to /content/attempt2_savedlr1/person_model.017.h5
# 360/360 [==============================] - 104s 288ms/step - loss: 7.8343 - gender_output_loss: 0.6817 - image_quality_output_loss: 0.9858 - age_output_loss: 1.4364 - weight_output_loss: 1.0015 - bag_output_loss: 0.9200 - footwear_output_loss: 0.9550 - pose_output_loss: 0.9350 - emotion_output_loss: 0.9188 - gender_output_acc: 0.5522 - image_quality_output_acc: 0.5501 - age_output_acc: 0.3943 - weight_output_acc: 0.6344 - bag_output_acc: 0.5621 - footwear_output_acc: 0.5587 - pose_output_acc: 0.6177 - emotion_output_acc: 0.7135 - val_loss: 7.9144 - val_gender_output_loss: 0.6764 - val_image_quality_output_loss: 0.9971 - val_age_output_loss: 1.4532 - val_weight_output_loss: 1.0094 - val_bag_output_loss: 0.9344 - val_footwear_output_loss: 0.9473 - val_pose_output_loss: 0.9482 - val_emotion_output_loss: 0.9485 - val_gender_output_acc: 0.5859 - val_image_quality_output_acc: 0.5504 - val_age_output_acc: 0.4032 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5565 - val_footwear_output_acc: 0.5665 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00018: val_loss improved from 7.91694 to 7.91445, saving model to /content/attempt2_savedlr1/person_model.018.h5
# Epoch 19/60
# 360/360 [==============================] - 103s 287ms/step - loss: 7.8369 - gender_output_loss: 0.6801 - image_quality_output_loss: 0.9846 - age_output_loss: 1.4375 - weight_output_loss: 1.0004 - bag_output_loss: 0.9208 - footwear_output_loss: 0.9618 - pose_output_loss: 0.9322 - emotion_output_loss: 0.9194 - gender_output_acc: 0.5614 - image_quality_output_acc: 0.5527 - age_output_acc: 0.3937 - weight_output_acc: 0.6342 - bag_output_acc: 0.5573 - footwear_output_acc: 0.5578 - pose_output_acc: 0.6175 - emotion_output_acc: 0.7135 - val_loss: 7.8895 - val_gender_output_loss: 0.6748 - val_image_quality_output_loss: 0.9869 - val_age_output_loss: 1.4499 - val_weight_output_loss: 1.0077 - val_bag_output_loss: 0.9335 - val_footwear_output_loss: 0.9438 - val_pose_output_loss: 0.9434 - val_emotion_output_loss: 0.9494 - val_gender_output_acc: 0.5746 - val_image_quality_output_acc: 0.5504 - val_age_output_acc: 0.4017 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5575 - val_footwear_output_acc: 0.5680 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00019: val_loss improved from 7.91445 to 7.88947, saving model to /content/attempt2_savedlr1/person_model.019.h5
# Epoch 20/60
# 359/360 [============================>.] - ETA: 0s - loss: 7.8397 - gender_output_loss: 0.6787 - image_quality_output_loss: 0.9867 - age_output_loss: 1.4381 - weight_output_loss: 1.0029 - bag_output_loss: 0.9186 - footwear_output_loss: 0.9632 - pose_output_loss: 0.9322 - emotion_output_loss: 0.9194 - gender_output_acc: 0.5628 - image_quality_output_acc: 0.5531 - age_output_acc: 0.3945 - weight_output_acc: 0.6348 - bag_output_acc: 0.5606 - footwear_output_acc: 0.5560 - pose_output_acc: 0.6176 - emotion_output_acc: 0.7132
# Epoch 00019: val_loss improved from 7.91445 to 7.88947, saving model to /content/attempt2_savedlr1/person_model.019.h5
# 360/360 [==============================] - 104s 289ms/step - loss: 7.8389 - gender_output_loss: 0.6788 - image_quality_output_loss: 0.9867 - age_output_loss: 1.4378 - weight_output_loss: 1.0029 - bag_output_loss: 0.9186 - footwear_output_loss: 0.9632 - pose_output_loss: 0.9323 - emotion_output_loss: 0.9186 - gender_output_acc: 0.5628 - image_quality_output_acc: 0.5530 - age_output_acc: 0.3947 - weight_output_acc: 0.6349 - bag_output_acc: 0.5608 - footwear_output_acc: 0.5563 - pose_output_acc: 0.6174 - emotion_output_acc: 0.7136 - val_loss: 7.8514 - val_gender_output_loss: 0.6749 - val_image_quality_output_loss: 0.9871 - val_age_output_loss: 1.4409 - val_weight_output_loss: 1.0000 - val_bag_output_loss: 0.9288 - val_footwear_output_loss: 0.9428 - val_pose_output_loss: 0.9415 - val_emotion_output_loss: 0.9354 - val_gender_output_acc: 0.5776 - val_image_quality_output_acc: 0.5504 - val_age_output_acc: 0.3992 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5570 - val_footwear_output_acc: 0.5630 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00020: val_loss improved from 7.88947 to 7.85140, saving model to /content/attempt2_savedlr1/person_model.020.h5
# Epoch 21/60
# 359/360 [============================>.] - ETA: 0s - loss: 7.8385 - gender_output_loss: 0.6785 - image_quality_output_loss: 0.9876 - age_output_loss: 1.4406 - weight_output_loss: 0.9992 - bag_output_loss: 0.9196 - footwear_output_loss: 0.9593 - pose_output_loss: 0.9334 - emotion_output_loss: 0.9203 - gender_output_acc: 0.5683 - image_quality_output_acc: 0.5528 - age_output_acc: 0.3912 - weight_output_acc: 0.6339 - bag_output_acc: 0.5648 - footwear_output_acc: 0.5584 - pose_output_acc: 0.6178 - emotion_output_acc: 0.7134
# Epoch 00020: val_loss improved from 7.88947 to 7.85140, saving model to /content/attempt2_savedlr1/person_model.020.h5
# 360/360 [==============================] - 104s 289ms/step - loss: 7.8394 - gender_output_loss: 0.6785 - image_quality_output_loss: 0.9881 - age_output_loss: 1.4407 - weight_output_loss: 0.9992 - bag_output_loss: 0.9199 - footwear_output_loss: 0.9590 - pose_output_loss: 0.9336 - emotion_output_loss: 0.9204 - gender_output_acc: 0.5683 - image_quality_output_acc: 0.5521 - age_output_acc: 0.3913 - weight_output_acc: 0.6337 - bag_output_acc: 0.5646 - footwear_output_acc: 0.5584 - pose_output_acc: 0.6176 - emotion_output_acc: 0.7134 - val_loss: 7.8745 - val_gender_output_loss: 0.6765 - val_image_quality_output_loss: 0.9949 - val_age_output_loss: 1.4400 - val_weight_output_loss: 1.0061 - val_bag_output_loss: 0.9272 - val_footwear_output_loss: 0.9427 - val_pose_output_loss: 0.9470 - val_emotion_output_loss: 0.9402 - val_gender_output_acc: 0.5852 - val_image_quality_output_acc: 0.5514 - val_age_output_acc: 0.3977 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5565 - val_footwear_output_acc: 0.5660 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00021: val_loss did not improve from 7.85140
# Epoch 22/60
# 359/360 [============================>.] - ETA: 0s - loss: 7.8279 - gender_output_loss: 0.6772 - image_quality_output_loss: 0.9868 - age_output_loss: 1.4363 - weight_output_loss: 0.9989 - bag_output_loss: 0.9202 - footwear_output_loss: 0.9549 - pose_output_loss: 0.9311 - emotion_output_loss: 0.9225 - gender_output_acc: 0.5634 - image_quality_output_acc: 0.5522 - age_output_acc: 0.3925 - weight_output_acc: 0.6334 - bag_output_acc: 0.5622 - footwear_output_acc: 0.5612 - pose_output_acc: 0.6181 - emotion_output_acc: 0.
- val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5580 - val_footwear_output_acc: 0.5751 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00031: val_loss did not improve from 7.79990
# Epoch 32/60
# 359/360 [============================>.] - ETA: 0s - loss: 7.7641 - gender_output_loss: 0.6703 - image_quality_output_loss: 0.9833 - age_output_loss: 1.4295 - weight_output_loss: 0.9930 - bag_output_loss: 0.9117 - footwear_output_loss: 0.9345 - pose_output_loss: 0.9276 - emotion_output_loss: 0.9142 - gender_output_acc: 0.5731 - image_quality_output_acc: 0.5522 - age_output_acc: 0.3955 - weight_output_acc: 0.6341 - bag_output_acc: 0.5610 - footwear_output_acc: 0.5756 - pose_output_acc: 0.6173 - emotion_output_acc: 0.7135
# 360/360 [==============================] - 105s 291ms/step - loss: 7.7646 - gender_output_loss: 0.6704 - image_quality_output_loss: 0.9837 - age_output_loss: 1.4294 - weight_output_loss: 0.9929 - bag_output_loss: 0.9117 - footwear_output_loss: 0.9347 - pose_output_loss: 0.9276 - emotion_output_loss: 0.9144 - gender_output_acc: 0.5728 - image_quality_output_acc: 0.5518 - age_output_acc: 0.3957 - weight_output_acc: 0.6343 - bag_output_acc: 0.5610 - footwear_output_acc: 0.5753 - pose_output_acc: 0.6174 - emotion_output_acc: 0.7134 - val_loss: 7.7942 - val_gender_output_loss: 0.6656 - val_image_quality_output_loss: 0.9873 - val_age_output_loss: 1.4326 - val_weight_output_loss: 0.9854 - val_bag_output_loss: 0.9237 - val_footwear_output_loss: 0.9237 - val_pose_output_loss: 0.9366 - val_emotion_output_loss: 0.9392 - val_gender_output_acc: 0.5902 - val_image_quality_output_acc: 0.5484 - val_age_output_acc: 0.3982 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5575 - val_footwear_output_acc: 0.5761 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00032: val_loss improved from 7.79990 to 7.79419, saving model to /content/attempt2_savedlr1/person_model.032.h5
# Epoch 33/60
# ...
#
# Epoch 00049: val_loss improved from 7.73970 to 7.73661, saving model to /content/attempt2_savedlr1/person_model.049.h5
# Epoch 50/60
# 359/360 [============================>.] - ETA: 0s - loss: 7.7224 - gender_output_loss: 0.6635 - image_quality_output_loss: 0.9806 - age_output_loss: 1.4215 - weight_output_loss: 0.9913 - bag_output_loss: 0.9118 - footwear_output_loss: 0.9228 - pose_output_loss: 0.9214 - emotion_output_loss: 0.9094 - gender_output_acc: 0.5834 - image_quality_output_acc: 0.5507 - age_output_acc: 0.3943 - weight_output_acc: 0.6339 - bag_output_acc: 0.5624 - footwear_output_acc: 0.5832 - pose_output_acc: 0.6177 - emotion_output_acc: 0.7136
# Epoch 00049: val_loss improved from 7.73970 to 7.73661, saving model to /content/attempt2_savedlr1/person_model.049.h5
# 360/360 [==============================] - 104s 289ms/step - loss: 7.7212 - gender_output_loss: 0.6635 - image_quality_output_loss: 0.9803 - age_output_loss: 1.4211 - weight_output_loss: 0.9912 - bag_output_loss: 0.9116 - footwear_output_loss: 0.9228 - pose_output_loss: 0.9213 - emotion_output_loss: 0.9094 - gender_output_acc: 0.5836 - image_quality_output_acc: 0.5509 - age_output_acc: 0.3947 - weight_output_acc: 0.6340 - bag_output_acc: 0.5628 - footwear_output_acc: 0.5832 - pose_output_acc: 0.6178 - emotion_output_acc: 0.
- val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5575 - val_footwear_output_acc: 0.5862 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00057: val_loss did not improve from 7.71818
# Epoch 58/60
# 360/360 [==============================] - 105s 292ms/step - loss: 7.7238 - gender_output_loss: 0.6635 - image_quality_output_loss: 0.9808 - age_output_loss: 1.4229 - weight_output_loss: 0.9895 - bag_output_loss: 0.9127 - footwear_output_loss: 0.9198 - pose_output_loss: 0.9242 - emotion_output_loss: 0.9104 - gender_output_acc: 0.5804 - image_quality_output_acc: 0.5523 - age_output_acc: 0.3973 - weight_output_acc: 0.6345 - bag_output_acc: 0.5624 - footwear_output_acc: 0.5862 - pose_output_acc: 0.6177 - emotion_output_acc: 0.7132 - val_loss: 7.7076 - val_gender_output_loss: 0.6574 - val_image_quality_output_loss: 0.9813 - val_age_output_loss: 1.4216 - val_weight_output_loss: 0.9726 - val_bag_output_loss: 0.9174 - val_footwear_output_loss: 0.9015 - val_pose_output_loss: 0.9256 - val_emotion_output_loss: 0.9303 - val_gender_output_acc: 0.6018 - val_image_quality_output_acc: 0.5529 - val_age_output_acc: 0.3921 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5570 - val_footwear_output_acc: 0.5882 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00057: val_loss did not improve from 7.71818
# Epoch 58/60
#
# Epoch 00058: val_loss improved from 7.71818 to 7.70765, saving model to /content/attempt2_savedlr1/person_model.058.h5
# Epoch 59/60
# 360/360 [==============================] - 104s 289ms/step - loss: 7.7053 - gender_output_loss: 0.6619 - image_quality_output_loss: 0.9807 - age_output_loss: 1.4231 - weight_output_loss: 0.9910 - bag_output_loss: 0.9103 - footwear_output_loss: 0.9104 - pose_output_loss: 0.9208 - emotion_output_loss: 0.9074 - gender_output_acc: 0.5777 - image_quality_output_acc: 0.5537 - age_output_acc: 0.3964 - weight_output_acc: 0.6346 - bag_output_acc: 0.5649 - footwear_output_acc: 0.5859 - pose_output_acc: 0.6177 - emotion_output_acc: 0.7136 - val_loss: 7.7135 - val_gender_output_loss: 0.6585 - val_image_quality_output_loss: 0.9825 - val_age_output_loss: 1.4226 - val_weight_output_loss: 0.9741 - val_bag_output_loss: 0.9211 - val_footwear_output_loss: 0.9022 - val_pose_output_loss: 0.9205 - val_emotion_output_loss: 0.9321 - val_gender_output_acc: 0.6013 - val_image_quality_output_acc: 0.5509 - val_age_output_acc: 0.3992 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5559 - val_footwear_output_acc: 0.5882 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00059: val_loss did not improve from 7.70765
# Epoch 60/60
# 360/360 [==============================] - 105s 291ms/step - loss: 7.6990 - gender_output_loss: 0.6619 - image_quality_output_loss: 0.9810 - age_output_loss: 1.4199 - weight_output_loss: 0.9901 - bag_output_loss: 0.9083 - footwear_output_loss: 0.9100 - pose_output_loss: 0.9180 - emotion_output_loss: 0.9098 - gender_output_acc: 0.5823 - image_quality_output_acc: 0.5538 - age_output_acc: 0.3978 - weight_output_acc: 0.6339 - bag_output_acc: 0.5650 - footwear_output_acc: 0.5899 - pose_output_acc: 0.6178 - emotion_output_acc: 0.7131 - val_loss: 7.7081 - val_gender_output_loss: 0.6573 - val_image_quality_output_loss: 0.9824 - val_age_output_loss: 1.4169 - val_weight_output_loss: 0.9762 - val_bag_output_loss: 0.9164 - val_footwear_output_loss: 0.8997 - val_pose_output_loss: 0.9245 - val_emotion_output_loss: 0.9348 - val_gender_output_acc: 0.6028 - val_image_quality_output_acc: 0.5509 - val_age_output_acc: 0.3977 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5570 - val_footwear_output_acc: 0.5948 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00060: val_loss did not improve from 7.70765

# %%
# view how LR has worked
clr_used = clr_exp
plt.xlabel('Training Iterations')
plt.ylabel('Learning Rate')
plt.title("CLR - 'Exponential' Policy")
plt.plot(clr_used.history['iterations'], clr_used.history['lr'])

# %%
# Load best saved model
from keras.models import load_model
best_model = load_model("/content/attempt2_savedlr1/person_model.058.h5")
best_model = model

# %%
# Evaluate Model for test data
results = best_model.evaluate_generator(valid_gen, verbose=1)
results_dict = dict(zip(best_model.metrics_names, results))
# Out:
# 31/31 [==============================] - 5s 156ms/step

# %%
# get accuracies for each category
acc_results = {name:result for name, result in zip(best_model.metrics_names, results) if name.endswith("acc")}
print("Total Validation Loss: ", results_dict['loss'])
print("Validation Accuracies: ")
acc_results
# Out:
# Total Validation Loss:  7.708139450319352
# Validation Accuracies:
# {'age_output_acc': 0.39768145161290325,
#  'bag_output_acc': 0.5569556451612904,
#  'emotion_output_acc': 0.7001008064516129,
#  'footwear_output_acc': 0.594758064516129,
#  'gender_output_acc': 0.6028225806451613,
#  'image_quality_output_acc': 0.5509072580645161,
#  'pose_output_acc': 0.6204637096774194,
#  'weight_output_acc': 0.6466733870967742}

# %%
model_itr2 = best_model

# %%
history2 = model_itr2.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    use_multiprocessing=True,
    workers=6, 
    epochs=20,
    verbose=1,
    callbacks=callbacks
)
# Out:
# Epoch 1/20
# 360/360 [==============================] - 109s 302ms/step - loss: 7.7013 - gender_output_loss: 0.6625 - image_quality_output_loss: 0.9792 - age_output_loss: 1.4230 - weight_output_loss: 0.9892 - bag_output_loss: 0.9096 - footwear_output_loss: 0.9100 - pose_output_loss: 0.9187 - emotion_output_loss: 0.9091 - gender_output_acc: 0.5827 - image_quality_output_acc: 0.5518 - age_output_acc: 0.3943 - weight_output_acc: 0.6344 - bag_output_acc: 0.5644 - footwear_output_acc: 0.5887 - pose_output_acc: 0.6178 - emotion_output_acc: 0.7134 - val_loss: 7.7001 - val_gender_output_loss: 0.6581 - val_image_quality_output_loss: 0.9840 - val_age_output_loss: 1.4178 - val_weight_output_loss: 0.9693 - val_bag_output_loss: 0.9165 - val_footwear_output_loss: 0.9003 - val_pose_output_loss: 0.9217 - val_emotion_output_loss: 0.9323 - val_gender_output_acc: 0.6041 - val_image_quality_output_acc: 0.5504 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5565 - val_footwear_output_acc: 0.5912 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00001: val_loss improved from 7.70765 to 7.70006, saving model to /content/attempt2_savedlr1/person_model.001.h5
# Epoch 2/20
# 359/360 [============================>.] - ETA: 0s - loss: 7.6901 - gender_output_loss: 0.6608 - image_quality_output_loss: 0.9807 - age_output_loss: 1.4195 - weight_output_loss: 0.9864 - bag_output_loss: 0.9086 - footwear_output_loss: 0.9058 - pose_output_loss: 0.9187 - emotion_output_loss: 0.9095 - gender_output_acc: 0.5858 - image_quality_output_acc: 0.5534 - age_output_acc: 0.3974 - weight_output_acc: 0.6345 - bag_output_acc: 0.5643 - footwear_output_acc: 0.5894 - pose_output_acc: 0.6179 - emotion_output_acc: 0.
- val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5570 - val_footwear_output_acc: 0.5897 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00012: val_loss improved from 7.68799 to 7.68209, saving model to /content/attempt2_savedlr1/person_model.012.h5
# Epoch 13/20
# 360/360 [==============================] - 105s 290ms/step - loss: 7.6881 - gender_output_loss: 0.6605 - image_quality_output_loss: 0.9805 - age_output_loss: 1.4204 - weight_output_loss: 0.9881 - bag_output_loss: 0.9086 - footwear_output_loss: 0.9031 - pose_output_loss: 0.9156 - emotion_output_loss: 0.9113 - gender_output_acc: 0.5843 - image_quality_output_acc: 0.5519 - age_output_acc: 0.3942 - weight_output_acc: 0.6344 - bag_output_acc: 0.5650 - footwear_output_acc: 0.5951 - pose_output_acc: 0.6177 - emotion_output_acc: 0.7133 - val_loss: 7.6794 - val_gender_output_loss: 0.6564 - val_image_quality_output_loss: 0.9801 - val_age_output_loss: 1.4172 - val_weight_output_loss: 0.9676 - val_bag_output_loss: 0.9137 - val_footwear_output_loss: 0.8930 - val_pose_output_loss: 0.9203 - val_emotion_output_loss: 0.9310 - val_gender_output_acc: 0.6061 - val_image_quality_output_acc: 0.5504 - val_age_output_acc: 0.3942 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5575 - val_footwear_output_acc: 0.5968 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00013: val_loss improved from 7.68209 to 7.67935, saving model to /content/attempt2_savedlr1/person_model.013.h5
# Epoch 14/20
# 359/360 [============================>.] - ETA: 0s - loss: 7.6910 - gender_output_loss: 0.6602 - image_quality_output_loss: 0.9797 - age_output_loss: 1.4206 - weight_output_loss: 0.9849 - bag_output_loss: 0.9093 - footwear_output_loss: 0.9074 - pose_output_loss: 0.9194 - emotion_output_loss: 0.9095 - gender_output_acc: 0.5873 - image_quality_output_acc: 0.5527 - age_output_acc: 0.3941 - weight_output_acc: 0.6345 - bag_output_acc: 0.5635 - footwear_output_acc: 0.5916 - pose_output_acc: 0.6183 - emotion_output_acc: 0.7133
# Epoch 00013: val_loss improved from 7.68209 to 7.67935, saving model to /content/attempt2_savedlr1/person_model.013.h5
# 360/360 [==============================] - 104s 290ms/step - loss: 7.6911 - gender_output_loss: 0.6602 - image_quality_output_loss: 0.9795 - age_output_loss: 1.4204 - weight_output_loss: 0.9854 - bag_output_loss: 0.9092 - footwear_output_loss: 0.9072 - pose_output_loss: 0.9199 - emotion_output_loss: 0.9093 - gender_output_acc: 0.5873 - image_quality_output_acc: 0.5528 - age_output_acc: 0.3944 - weight_output_acc: 0.6344 - bag_output_acc: 0.5635 - footwear_output_acc: 0.5918 - pose_output_acc: 0.6179 - emotion_output_acc: 0.7135 - val_loss: 7.6825 - val_gender_output_loss: 0.6552 - val_image_quality_output_loss: 0.9824 - val_age_output_loss: 1.4161 - val_weight_output_loss: 0.9750 - val_bag_output_loss: 0.9149 - val_footwear_output_loss: 0.8904 - val_pose_output_loss: 0.9191 - val_emotion_output_loss: 0.9295 - val_gender_output_acc: 0.5985 - val_image_quality_output_acc: 0.5509 - val_age_output_acc: 0.3997 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5559 - val_footwear_output_acc: 0.5927 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 
- val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00018: val_loss did not improve from 7.67935
# Epoch 19/20
# 360/360 [==============================] - 106s 294ms/step - loss: 7.6710 - gender_output_loss: 0.6581 - image_quality_output_loss: 0.9791 - age_output_loss: 1.4193 - weight_output_loss: 0.9873 - bag_output_loss: 0.9085 - footwear_output_loss: 0.8974 - pose_output_loss: 0.9126 - emotion_output_loss: 0.9087 - gender_output_acc: 0.5895 - image_quality_output_acc: 0.5539 - age_output_acc: 0.3954 - weight_output_acc: 0.6345 - bag_output_acc: 0.5662 - footwear_output_acc: 0.5978 - pose_output_acc: 0.6175 - emotion_output_acc: 0.7134 - val_loss: 7.6772 - val_gender_output_loss: 0.6536 - val_image_quality_output_loss: 0.9820 - val_age_output_loss: 1.4169 - val_weight_output_loss: 0.9725 - val_bag_output_loss: 0.9150 - val_footwear_output_loss: 0.8881 - val_pose_output_loss: 0.9186 - val_emotion_output_loss: 0.9305 - val_gender_output_acc: 0.6116 - val_image_quality_output_acc: 0.5479 - val_age_output_acc: 0.3926 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5570 - val_footwear_output_acc: 0.6013 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00019: val_loss improved from 7.67935 to 7.67723, saving model to /content/attempt2_savedlr1/person_model.019.h5
# Epoch 20/20
# 360/360 [==============================] - 105s 291ms/step - loss: 7.6617 - gender_output_loss: 0.6571 - image_quality_output_loss: 0.9802 - age_output_loss: 1.4153 - weight_output_loss: 0.9852 - bag_output_loss: 0.9079 - footwear_output_loss: 0.8970 - pose_output_loss: 0.9106 - emotion_output_loss: 0.9084 - gender_output_acc: 0.5882 - image_quality_output_acc: 0.5530 - age_output_acc: 0.4001 - weight_output_acc: 0.6344 - bag_output_acc: 0.5647 - footwear_output_acc: 0.5941 - pose_output_acc: 0.6177 - emotion_output_acc: 0.7134 - val_loss: 7.6741 - val_gender_output_loss: 0.6536 - val_image_quality_output_loss: 0.9825 - val_age_output_loss: 1.4168 - val_weight_output_loss: 0.9715 - val_bag_output_loss: 0.9147 - val_footwear_output_loss: 0.8878 - val_pose_output_loss: 0.9160 - val_emotion_output_loss: 0.9311 - val_gender_output_acc: 0.6124 - val_image_quality_output_acc: 0.5489 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6467 - val_bag_output_acc: 0.5559 - val_footwear_output_acc: 0.6008 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.7001
#
# Epoch 00020: val_loss improved from 7.67723 to 7.67410, saving model to /content/attempt2_savedlr1/person_model.020.h5

# %%
# Load best saved model
from keras.models import load_model
best_model = load_model("/content/attempt2_savedlr1/person_model.020.h5")
best_model = model

# %%
# Evaluate Model for test data
results = best_model.evaluate_generator(valid_gen, verbose=1)
results_dict = dict(zip(best_model.metrics_names, results))
# Out:
# 31/31 [==============================] - 5s 159ms/step

# %%
# get accuracies for each category
acc_results = {name:result for name, result in zip(best_model.metrics_names, results) if name.endswith("acc")}
print("Total Validation Loss: ", results_dict['loss'])
print("Validation Accuracies: ")
acc_results
# Out:
# Total Validation Loss:  7.674099153087985
# Validation Accuracies:
# {'age_output_acc': 0.3956653225806452,
#  'bag_output_acc': 0.5559475806451613,
#  'emotion_output_acc': 0.7001008064516129,
#  'footwear_output_acc': 0.6008064516129032,
#  'gender_output_acc': 0.6123991935483871,
#  'image_quality_output_acc': 0.5488911290322581,
#  'pose_output_acc': 0.6204637096774194,
#  'weight_output_acc': 0.6466733870967742}

# %%
# view how LR has worked
clr_used = clr_exp
plt.xlabel('Training Iterations')
plt.ylabel('Learning Rate')
plt.title("CLR - 'Exponential' Policy")
plt.plot(clr_used.history['iterations'], clr_used.history['lr'])
